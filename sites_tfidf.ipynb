# %%
import math
import os
from collections import Counter, OrderedDict

# %%
parsed_sites_directory = 'parsed_sites'


def tf(word, doc_word_counts):
    return doc_word_counts[word] / sum(doc_word_counts.values())


def n_containing(word, docs_contents):
    return sum(1 for doc in docs_contents if word in docs_contents[doc])


def idf(word, docs_contents):
    return math.log(len(docs_contents) / n_containing(word, docs_contents))


def tfidf(word, doc_word_counts, docs_contents):
    return(tf(word, doc_word_counts) * idf(word, docs_contents))

# %%
docs = {fname for fname in os.listdir(parsed_sites_directory) if fname.startswith('http')}
docs_contents = {}

for doc in docs:
    doc_path = '{}/{}'.format(parsed_sites_directory, doc)
    with open(doc_path) as fp:
        docs_contents[doc] = dict(Counter([word.strip() for word in fp]))

for doc, doc_word_counts in docs_contents.items():
    print('Top words in document: {}'.format(doc))
    scores = {word: tfidf(word, doc_word_counts, docs_contents) for word in doc_word_counts}
    sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    for word, score in sorted_words[:500]:
        print('\tWord: {}\tTD-IDF: {}'.format(word, round(score, 5)))
# Out:
# Top words in document: http:www.cmaf.ru
# 	Word: скрытие	TD-IDF: 0.01052
# 	Word: enter	TD-IDF: 0.01041
# 	Word: автоинформатор	TD-IDF: 0.00757
# 	Word: цмвс	TD-IDF: 0.00693
# 	Word: удалять	TD-IDF: 0.00433
# 	Word: влево	TD-IDF: 0.00362
# 	Word: мышка	TD-IDF: 0.00362
# 	Word: вооружённый	TD-IDF: 0.00355
# 	Word: поворот	TD-IDF: 0.00335
# 	Word: кнопка	TD-IDF: 0.00332
# 	Word: контейнер	TD-IDF: 0.00324
# 	Word: вдв	TD-IDF: 0.00323
# 	Word: ввод	TD-IDF: 0.0031
# 	Word: прекращать	TD-IDF: 0.00275
# 	Word: десантный	TD-IDF: 0.00263
# 	Word: вт	TD-IDF: 0.0024
# 	Word: бронекатер	TD-IDF: 0.00235
# 	Word: бункер	TD-IDF: 0.0022
# 	Word: нажать	TD-IDF: 0.00218
# 	Word: пн	TD-IDF: 0.00208
# 	Word: воздушно	TD-IDF: 0.00193
# 	Word: бк	TD-IDF: 0.00183
# 	Word: фондовый	TD-IDF: 0.00177
# 	Word: армия	TD-IDF: 0.00167
# 	Word: задний	TD-IDF: 0.00166
# 	Word: отправка	TD-IDF: 0.00159
# 	Word: кинофононегативный	TD-IDF: 0.00152
# 	Word: стрелка	TD-IDF: 0.00147
# 	Word: факс	TD-IDF: 0.0014
# 	Word: контент	TD-IDF: 0.00137
# 	Word: демьян	TD-IDF: 0.00135
# 	Word: экскурсионный	TD-IDF: 0.00132
# 	Word: фотогалерея	TD-IDF: 0.0013
# 	Word: стандартный	TD-IDF: 0.00129
# 	Word: устанавливать	TD-IDF: 0.00129
# 	Word: ошибка	TD-IDF: 0.00129
# 	Word: сила	TD-IDF: 0.00119
# 	Word: оборона	TD-IDF: 0.00118
# 	Word: противовоздушный	TD-IDF: 0.00117
# 	Word: эксурсионный	TD-IDF: 0.00117
# 	Word: люцкан	TD-IDF: 0.00117
# 	Word: дочев	TD-IDF: 0.00117
# 	Word: цмка	TD-IDF: 0.00117
# 	Word: сталин	TD-IDF: 0.00113
# 	Word: войско	TD-IDF: 0.00113
# 	Word: ракетный	TD-IDF: 0.00107
# 	Word: защитить	TD-IDF: 0.00106
# 	Word: бариевый	TD-IDF: 0.00105
# 	Word: указание	TD-IDF: 0.00105
# 	Word: минобороны	TD-IDF: 0.00103
# 	Word: кольт	TD-IDF: 0.00103
# 	Word: врангеля	TD-IDF: 0.00101
# 	Word: маршал	TD-IDF: 0.00101
# 	Word: цаликов	TD-IDF: 0.00096
# 	Word: рвсна	TD-IDF: 0.00096
# 	Word: грохольский	TD-IDF: 0.00096
# 	Word: всеармейский	TD-IDF: 0.00094
# 	Word: федерация	TD-IDF: 0.00092
# 	Word: проезд	TD-IDF: 0.00091
# 	Word: пт	TD-IDF: 0.00088
# 	Word: сб	TD-IDF: 0.00088
# 	Word: обслуживание	TD-IDF: 0.00088
# 	Word: флаг	TD-IDF: 0.00087
# 	Word: вещевой	TD-IDF: 0.00086
# 	Word: секретарь	TD-IDF: 0.00085
# 	Word: ркк	TD-IDF: 0.00084
# 	Word: цыган	TD-IDF: 0.00084
# 	Word: поль	TD-IDF: 0.00083
# 	Word: десантник	TD-IDF: 0.00082
# 	Word: петляков	TD-IDF: 0.00082
# 	Word: главнокомандующий	TD-IDF: 0.00082
# 	Word: схема	TD-IDF: 0.00081
# 	Word: свойство	TD-IDF: 0.00081
# 	Word: начальный	TD-IDF: 0.00081
# 	Word: присяга	TD-IDF: 0.00081
# 	Word: бюро	TD-IDF: 0.0008
# 	Word: военный	TD-IDF: 0.0008
# 	Word: рвс	TD-IDF: 0.00077
# 	Word: фотофонд	TD-IDF: 0.00077
# 	Word: вневедомственный	TD-IDF: 0.00076
# 	Word: брежнев	TD-IDF: 0.00075
# 	Word: закрытие	TD-IDF: 0.00074
# 	Word: знамя	TD-IDF: 0.00071
# 	Word: знаменный	TD-IDF: 0.00071
# 	Word: вооружение	TD-IDF: 0.00071
# 	Word: филиал	TD-IDF: 0.0007
# 	Word: фоп	TD-IDF: 0.0007
# 	Word: текст	TD-IDF: 0.0007
# 	Word: револьвер	TD-IDF: 0.00068
# 	Word: обслуживания	TD-IDF: 0.00067
# 	Word: отдельного	TD-IDF: 0.00067
# 	Word: продолжительность	TD-IDF: 0.00067
# 	Word: определение	TD-IDF: 0.00067
# 	Word: флотский	TD-IDF: 0.00065
# 	Word: бедный	TD-IDF: 0.00064
# 	Word: страница	TD-IDF: 0.00064
# 	Word: тодора	TD-IDF: 0.00063
# 	Word: вс	TD-IDF: 0.00062
# 	Word: музей	TD-IDF: 0.00061
# 	Word: выделить	TD-IDF: 0.00061
# 	Word: окб	TD-IDF: 0.0006
# 	Word: гвардейский	TD-IDF: 0.0006
# 	Word: жуков	TD-IDF: 0.0006
# 	Word: дивизия	TD-IDF: 0.00059
# 	Word: занятия	TD-IDF: 0.00059
# 	Word: центральному	TD-IDF: 0.00059
# 	Word: конкурса	TD-IDF: 0.00059
# 	Word: форма	TD-IDF: 0.00059
# 	Word: 2000р	TD-IDF: 0.00058
# 	Word: форд	TD-IDF: 0.00058
# 	Word: батальон	TD-IDF: 0.00058
# 	Word: чело	TD-IDF: 0.00057
# 	Word: стиль	TD-IDF: 0.00057
# 	Word: никон	TD-IDF: 0.00057
# 	Word: контактный	TD-IDF: 0.00055
# 	Word: шевцов	TD-IDF: 0.00055
# 	Word: глубина	TD-IDF: 0.00054
# 	Word: сердюк	TD-IDF: 0.00053
# 	Word: российской	TD-IDF: 0.00053
# 	Word: интендантский	TD-IDF: 0.0005
# 	Word: боев	TD-IDF: 0.0005
# 	Word: российский	TD-IDF: 0.0005
# 	Word: воин	TD-IDF: 0.0005
# 	Word: генерал	TD-IDF: 0.00049
# 	Word: 25	TD-IDF: 0.00048
# 	Word: флот	TD-IDF: 0.00048
# 	Word: цдка	TD-IDF: 0.00048
# 	Word: вых	TD-IDF: 0.00048
# 	Word: искать	TD-IDF: 0.00047
# 	Word: сравнить	TD-IDF: 0.00047
# 	Word: битва	TD-IDF: 0.00047
# 	Word: орден	TD-IDF: 0.00047
# 	Word: обазюк	TD-IDF: 0.00047
# 	Word: удостоверять	TD-IDF: 0.00047
# 	Word: минута	TD-IDF: 0.00046
# 	Word: вмф	TD-IDF: 0.00046
# 	Word: худо	TD-IDF: 0.00046
# 	Word: рубль	TD-IDF: 0.00045
# 	Word: финансовый	TD-IDF: 0.00045
# 	Word: статс	TD-IDF: 0.00045
# 	Word: измайлово	TD-IDF: 0.00045
# 	Word: палехский	TD-IDF: 0.00044
# 	Word: режим	TD-IDF: 0.00044
# 	Word: военачальник	TD-IDF: 0.00044
# 	Word: бессонов	TD-IDF: 0.00043
# 	Word: мб	TD-IDF: 0.00043
# 	Word: закрытый	TD-IDF: 0.00042
# 	Word: внештатный	TD-IDF: 0.00041
# 	Word: цена	TD-IDF: 0.00041
# 	Word: война	TD-IDF: 0.00041
# 	Word: америкать	TD-IDF: 0.00041
# 	Word: министр	TD-IDF: 0.00041
# 	Word: кабинет	TD-IDF: 0.0004
# 	Word: цк	TD-IDF: 0.00039
# 	Word: ветеран	TD-IDF: 0.00039
# 	Word: балабаново	TD-IDF: 0.00038
# 	Word: рвср	TD-IDF: 0.00038
# 	Word: лукулла	TD-IDF: 0.00038
# 	Word: межвоенный	TD-IDF: 0.00038
# 	Word: центральный	TD-IDF: 0.00038
# 	Word: атташе	TD-IDF: 0.00038
# 	Word: белград	TD-IDF: 0.00038
# 	Word: четырежды	TD-IDF: 0.00038
# 	Word: суб	TD-IDF: 0.00038
# 	Word: cтоимость	TD-IDF: 0.00038
# 	Word: шемановский	TD-IDF: 0.00038
# 	Word: майор	TD-IDF: 0.00037
# 	Word: полковник	TD-IDF: 0.00037
# 	Word: пасхальный	TD-IDF: 0.00037
# 	Word: яйцо	TD-IDF: 0.00037
# 	Word: стрелковый	TD-IDF: 0.00037
# 	Word: кпсс	TD-IDF: 0.00037
# 	Word: кроме	TD-IDF: 0.00037
# 	Word: архив	TD-IDF: 0.00037
# 	Word: положение	TD-IDF: 0.00037
# 	Word: следственный	TD-IDF: 0.00037
# 	Word: наградной	TD-IDF: 0.00037
# 	Word: автомобильный	TD-IDF: 0.00036
# 	Word: мещанский	TD-IDF: 0.00036
# 	Word: войсковой	TD-IDF: 0.00036
# 	Word: её	TD-IDF: 0.00036
# 	Word: физкультурный	TD-IDF: 0.00036
# 	Word: придвор	TD-IDF: 0.00035
# 	Word: знаменск	TD-IDF: 0.00035
# 	Word: востротин	TD-IDF: 0.00035
# 	Word: нэо	TD-IDF: 0.00035
# 	Word: кнутов	TD-IDF: 0.00035
# 	Word: локхид	TD-IDF: 0.00035
# 	Word: штейнмец	TD-IDF: 0.00035
# 	Word: курский	TD-IDF: 0.00035
# 	Word: год	TD-IDF: 0.00035
# 	Word: дополнительный	TD-IDF: 0.00034
# 	Word: панк	TD-IDF: 0.00034
# 	Word: фрунзе	TD-IDF: 0.00034
# 	Word: эмблема	TD-IDF: 0.00034
# 	Word: длить	TD-IDF: 0.00034
# 	Word: знаменка	TD-IDF: 0.00034
# 	Word: церемония	TD-IDF: 0.00033
# 	Word: коллекционный	TD-IDF: 0.00033
# 	Word: торжественный	TD-IDF: 0.00033
# 	Word: парашютный	TD-IDF: 0.00033
# 	Word: диорама	TD-IDF: 0.00032
# 	Word: крейсер	TD-IDF: 0.00032
# 	Word: цыганский	TD-IDF: 0.00032
# 	Word: научный	TD-IDF: 0.00032
# 	Word: командующий	TD-IDF: 0.00032
# 	Word: история	TD-IDF: 0.00032
# 	Word: монино	TD-IDF: 0.00032
# 	Word: флотилия	TD-IDF: 0.00032
# 	Word: воинский	TD-IDF: 0.00031
# 	Word: китель	TD-IDF: 0.00031
# 	Word: измайловский	TD-IDF: 0.00031
# 	Word: мвк	TD-IDF: 0.00031
# 	Word: для	TD-IDF: 0.00031
# 	Word: сталинградский	TD-IDF: 0.00031
# 	Word: коллекция	TD-IDF: 0.0003
# 	Word: пур	TD-IDF: 0.0003
# 	Word: входной	TD-IDF: 0.0003
# 	Word: элемент	TD-IDF: 0.0003
# 	Word: советский	TD-IDF: 0.0003
# 	Word: конев	TD-IDF: 0.00029
# 	Word: скорбь	TD-IDF: 0.00029
# 	Word: партнёр	TD-IDF: 0.00029
# 	Word: родина	TD-IDF: 0.00029
# 	Word: возложение	TD-IDF: 0.00029
# 	Word: лаковый	TD-IDF: 0.00029
# 	Word: цмс	TD-IDF: 0.00029
# 	Word: зрк	TD-IDF: 0.00029
# 	Word: дубынин	TD-IDF: 0.00029
# 	Word: секретность	TD-IDF: 0.00029
# 	Word: трофейный	TD-IDF: 0.00029
# 	Word: экономический	TD-IDF: 0.00028
# 	Word: боевой	TD-IDF: 0.00028
# 	Word: командование	TD-IDF: 0.00028
# 	Word: чаэс	TD-IDF: 0.00028
# 	Word: ссср	TD-IDF: 0.00028
# 	Word: ул	TD-IDF: 0.00027
# 	Word: пво	TD-IDF: 0.00027
# 	Word: белгородский	TD-IDF: 0.00027
# 	Word: болгария	TD-IDF: 0.00027
# 	Word: фронт	TD-IDF: 0.00027
# 	Word: ракета	TD-IDF: 0.00027
# 	Word: право	TD-IDF: 0.00027
# 	Word: подвиг	TD-IDF: 0.00027
# 	Word: стратегический	TD-IDF: 0.00027
# 	Word: сухопутный	TD-IDF: 0.00027
# 	Word: бонн	TD-IDF: 0.00027
# 	Word: июнь	TD-IDF: 0.00026
# 	Word: учащийся	TD-IDF: 0.00026
# 	Word: зал	TD-IDF: 0.00026
# 	Word: афганистан	TD-IDF: 0.00026
# 	Word: партизанский	TD-IDF: 0.00026
# 	Word: полотнище	TD-IDF: 0.00026
# 	Word: нахимовский	TD-IDF: 0.00026
# 	Word: заместитель	TD-IDF: 0.00026
# 	Word: кнут	TD-IDF: 0.00025
# 	Word: реликвия	TD-IDF: 0.00025
# 	Word: главком	TD-IDF: 0.00025
# 	Word: реликвийный	TD-IDF: 0.00025
# 	Word: бронетанковый	TD-IDF: 0.00025
# 	Word: пдп	TD-IDF: 0.00025
# 	Word: френч	TD-IDF: 0.00025
# 	Word: эйзенхауэр	TD-IDF: 0.00025
# 	Word: буторин	TD-IDF: 0.00025
# 	Word: имз	TD-IDF: 0.00025
# 	Word: одежда	TD-IDF: 0.00024
# 	Word: гитлер	TD-IDF: 0.00024
# 	Word: начальник	TD-IDF: 0.00024
# 	Word: лейтенант	TD-IDF: 0.00024
# 	Word: психолог	TD-IDF: 0.00024
# 	Word: великий	TD-IDF: 0.00024
# 	Word: бой	TD-IDF: 0.00024
# 	Word: оружие	TD-IDF: 0.00023
# 	Word: керченско	TD-IDF: 0.00023
# 	Word: багмета	TD-IDF: 0.00023
# 	Word: цыганского народ	TD-IDF: 0.00023
# 	Word: мто	TD-IDF: 0.00023
# 	Word: шкаторина	TD-IDF: 0.00023
# 	Word: даватец	TD-IDF: 0.00023
# 	Word: стромынский	TD-IDF: 0.00023
# 	Word: неравносторонний	TD-IDF: 0.00023
# 	Word: вдд	TD-IDF: 0.00023
# 	Word: жимерский	TD-IDF: 0.00023
# 	Word: д’эспозицион	TD-IDF: 0.00023
# 	Word: мстёрский	TD-IDF: 0.00023
# 	Word: чикуриный	TD-IDF: 0.00023
# 	Word: бтить	TD-IDF: 0.00023
# 	Word: мо	TD-IDF: 0.00023
# 	Word: союз	TD-IDF: 0.00023
# 	Word: го	TD-IDF: 0.00023
# 	Word: противник	TD-IDF: 0.00023
# 	Word: семченко	TD-IDF: 0.00023
# 	Word: работа	TD-IDF: 0.00023
# 	Word: офицер	TD-IDF: 0.00023
# 	Word: касса	TD-IDF: 0.00022
# 	Word: штаб	TD-IDF: 0.00022
# 	Word: фашистский	TD-IDF: 0.00022
# 	Word: авиация	TD-IDF: 0.00022
# 	Word: полководец	TD-IDF: 0.00022
# 	Word: рф	TD-IDF: 0.00022
# 	Word: назначение	TD-IDF: 0.00022
# 	Word: подарочный	TD-IDF: 0.00022
# 	Word: пу	TD-IDF: 0.00022
# 	Word: полка	TD-IDF: 0.00022
# 	Word: территориальный	TD-IDF: 0.00022
# 	Word: курсант	TD-IDF: 0.00021
# 	Word: корабельный	TD-IDF: 0.00021
# 	Word: аэродром	TD-IDF: 0.00021
# 	Word: подопечный	TD-IDF: 0.00021
# 	Word: ставка	TD-IDF: 0.00021
# 	Word: минимальный	TD-IDF: 0.00021
# 	Word: награда	TD-IDF: 0.00021
# 	Word: суворовский	TD-IDF: 0.00021
# 	Word: просветительный	TD-IDF: 0.00021
# 	Word: стадион	TD-IDF: 0.00021
# 	Word: деникин	TD-IDF: 0.00021
# 	Word: шефский	TD-IDF: 0.00021
# 	Word: победа	TD-IDF: 0.0002
# 	Word: подземный	TD-IDF: 0.0002
# 	Word: адрес	TD-IDF: 0.0002
# 	Word: экспозиция	TD-IDF: 0.0002
# 	Word: сторона	TD-IDF: 0.0002
# 	Word: фонд	TD-IDF: 0.0002
# 	Word: власих	TD-IDF: 0.00019
# 	Word: федянина	TD-IDF: 0.00019
# 	Word: сотрудни­к	TD-IDF: 0.00019
# 	Word: бы­ть	TD-IDF: 0.00019
# 	Word: прозор	TD-IDF: 0.00019
# 	Word: цдса	TD-IDF: 0.00019
# 	Word: селезневский	TD-IDF: 0.00019
# 	Word: гюйс	TD-IDF: 0.00019
# 	Word: партер	TD-IDF: 0.00019
# 	Word: павличенко	TD-IDF: 0.00019
# 	Word: ибаррурить	TD-IDF: 0.00019
# 	Word: талалихин	TD-IDF: 0.00019
# 	Word: шухмина	TD-IDF: 0.00019
# 	Word: покрышкин	TD-IDF: 0.00019
# 	Word: парламентёр	TD-IDF: 0.00019
# 	Word: кейтель	TD-IDF: 0.00019
# 	Word: империалист	TD-IDF: 0.00019
# 	Word: буреев	TD-IDF: 0.00019
# 	Word: адыга	TD-IDF: 0.00019
# 	Word: период	TD-IDF: 0.00019
# 	Word: награждать	TD-IDF: 0.00019
# 	Word: фгб	TD-IDF: 0.00019
# 	Word: яндекс	TD-IDF: 0.00019
# 	Word: советско	TD-IDF: 0.00019
# 	Word: реввоенсовет	TD-IDF: 0.00019
# 	Word: баллистический	TD-IDF: 0.00019
# 	Word: гимнастёрка	TD-IDF: 0.00019
# 	Word: холуй	TD-IDF: 0.00019
# 	Word: китай	TD-IDF: 0.00019
# 	Word: щит	TD-IDF: 0.00019
# 	Word: москва	TD-IDF: 0.00018
# 	Word: корнилов	TD-IDF: 0.00018
# 	Word: мундир	TD-IDF: 0.00018
# 	Word: разведчик	TD-IDF: 0.00018
# 	Word: новость	TD-IDF: 0.00018
# 	Word: техника	TD-IDF: 0.00018
# 	Word: посольство	TD-IDF: 0.00018
# 	Word: са	TD-IDF: 0.00018
# 	Word: воздушный	TD-IDF: 0.00018
# 	Word: нарком	TD-IDF: 0.00018
# 	Word: чеченский	TD-IDF: 0.00018
# 	Word: чапаев	TD-IDF: 0.00018
# 	Word: состояться	TD-IDF: 0.00018
# 	Word: выставка	TD-IDF: 0.00018
# 	Word: кропоткин	TD-IDF: 0.00018
# 	Word: миротворческий	TD-IDF: 0.00018
# 	Word: диагональный	TD-IDF: 0.00018
# 	Word: водрузить	TD-IDF: 0.00018
# 	Word: состязание	TD-IDF: 0.00018
# 	Word: герой	TD-IDF: 0.00018
# 	Word: артиллерийский	TD-IDF: 0.00018
# 	Word: ст	TD-IDF: 0.00017
# 	Word: агрессия	TD-IDF: 0.00017
# 	Word: зао	TD-IDF: 0.00017
# 	Word: обучающийся	TD-IDF: 0.00017
# 	Word: узнать	TD-IDF: 0.00017
# 	Word: трибуна	TD-IDF: 0.00017
# 	Word: двуглавый	TD-IDF: 0.00017
# 	Word: василевский	TD-IDF: 0.00017
# 	Word: ангар	TD-IDF: 0.00017
# 	Word: самолёт	TD-IDF: 0.00017
# 	Word: яхта	TD-IDF: 0.00017
# 	Word: униформа	TD-IDF: 0.00017
# 	Word: пространство	TD-IDF: 0.00017
# 	Word: краснофлотец	TD-IDF: 0.00017
# 	Word: ракетчик	TD-IDF: 0.00017
# 	Word: 1944г	TD-IDF: 0.00017
# 	Word: статут	TD-IDF: 0.00017
# 	Word: проектировка	TD-IDF: 0.00017
# 	Word: рейхсканцелярия	TD-IDF: 0.00017
# 	Word: бронепоезд	TD-IDF: 0.00017
# 	Word: куркин	TD-IDF: 0.00017
# 	Word: вакансия	TD-IDF: 0.00017
# 	Word: кинозал	TD-IDF: 0.00017
# 	Word: группа	TD-IDF: 0.00017
# 	Word: полиция	TD-IDF: 0.00017
# 	Word: страдание	TD-IDF: 0.00017
# 	Word: патриот	TD-IDF: 0.00017
# 	Word: авария	TD-IDF: 0.00016
# 	Word: говоров	TD-IDF: 0.00016
# 	Word: двина	TD-IDF: 0.00016
# 	Word: экспонат	TD-IDF: 0.00016
# 	Word: рота	TD-IDF: 0.00016
# 	Word: патриотический	TD-IDF: 0.00016
# 	Word: белгород	TD-IDF: 0.00016
# 	Word: воск	TD-IDF: 0.00016
# 	Word: реформирование	TD-IDF: 0.00016
# 	Word: логинов	TD-IDF: 0.00016
# 	Word: осетия	TD-IDF: 0.00016
# 	Word: ворошилов	TD-IDF: 0.00016
# 	Word: гражданский	TD-IDF: 0.00016
# 	Word: снаряжение	TD-IDF: 0.00016
# 	Word: шкатулка	TD-IDF: 0.00016
# 	Word: орёл	TD-IDF: 0.00016
# 	Word: верховный	TD-IDF: 0.00016
# 	Word: республика	TD-IDF: 0.00016
# 	Word: отечественный	TD-IDF: 0.00016
# 	Word: летие	TD-IDF: 0.00015
# 	Word: генеральный	TD-IDF: 0.00015
# 	Word: хiv	TD-IDF: 0.00015
# 	Word: старшина	TD-IDF: 0.00015
# 	Word: воздвиженка	TD-IDF: 0.00015
# 	Word: километровый	TD-IDF: 0.00015
# 	Word: штурмовой	TD-IDF: 0.00015
# 	Word: автомобилист	TD-IDF: 0.00015
# 	Word: квеста	TD-IDF: 0.00015
# 	Word: корабль	TD-IDF: 0.00015
# 	Word: мемориальный	TD-IDF: 0.00015
# 	Word: геральдический	TD-IDF: 0.00015
# 	Word: часть	TD-IDF: 0.00015
# 	Word: карлсхорст	TD-IDF: 0.00015
# 	Word: трехлинейный	TD-IDF: 0.00015
# 	Word: тоф	TD-IDF: 0.00015
# 	Word: халхина	TD-IDF: 0.00015
# 	Word: распростереть	TD-IDF: 0.00015
# 	Word: перекрещенный	TD-IDF: 0.00015
# 	Word: нумеровать	TD-IDF: 0.00015
# 	Word: шестиугольник	TD-IDF: 0.00015
# 	Word: михая	TD-IDF: 0.00015
# 	Word: маргеловый	TD-IDF: 0.00015
# 	Word: милитаристский	TD-IDF: 0.00015
# 	Word: обагрить	TD-IDF: 0.00015
# 	Word: ультиматум	TD-IDF: 0.00015
# 	Word: просчёт	TD-IDF: 0.00015
# 	Word: мстёра	TD-IDF: 0.00015
# 	Word: ватагин	TD-IDF: 0.00015
# 	Word: департамент	TD-IDF: 0.00015
# 	Word: лицей	TD-IDF: 0.00015
# 	Word: операция	TD-IDF: 0.00015
# 	Word: разгром	TD-IDF: 0.00015
# 	Word: фрг	TD-IDF: 0.00015
# 	Word: фронтовой	TD-IDF: 0.00015
# 	Word: перевезти	TD-IDF: 0.00014
# 	Word: отличиться	TD-IDF: 0.00014
# 	Word: смотровой	TD-IDF: 0.00014
# 	Word: маршрутный	TD-IDF: 0.00014
# 	Word: греков	TD-IDF: 0.00014
# 	Word: катер	TD-IDF: 0.00014
# 	Word: доб	TD-IDF: 0.00014
# 	Word: вековой	TD-IDF: 0.00014
# 	Word: кадетский	TD-IDF: 0.00014
# 	Word: файл	TD-IDF: 0.00014
# 	Word: антибольшевистский	TD-IDF: 0.00014
# 	Word: белградский	TD-IDF: 0.00014
# 	Word: дунайский	TD-IDF: 0.00014
# 	Word: 1957г	TD-IDF: 0.00014
# 	Word: межвидовой	TD-IDF: 0.00014
# 	Word: барышев	TD-IDF: 0.00014
# 	Word: врио	TD-IDF: 0.00014
# 	Word: баграмян	TD-IDF: 0.00014
# 	Word: подвойский	TD-IDF: 0.00014
# 	Word: бурка	TD-IDF: 0.00014
# 	Word: монтгомери	TD-IDF: 0.00014
# 	Word: карат	TD-IDF: 0.00014
# 	Word: выцветание	TD-IDF: 0.00014
# 	Word: нанкин	TD-IDF: 0.00014
# 	Word: кениг	TD-IDF: 0.00014
# 	Word: черняховский	TD-IDF: 0.00014
# 	Word: геройство	TD-IDF: 0.00014
# 	Word: калашников	TD-IDF: 0.00014
# 	Word: полк	TD-IDF: 0.00014
# 	Word: престарелый	TD-IDF: 0.00014
# 	Word: обмундирование	TD-IDF: 0.00014
# 	Word: сербский	TD-IDF: 0.00014
# 	Word: шапошников	TD-IDF: 0.00014
# 	Word: года ть	TD-IDF: 0.00014
# 	Word: пострелять	TD-IDF: 0.00014
# 	Word: ямало	TD-IDF: 0.00014
# 	Word: летательный	TD-IDF: 0.00014
# 	Word: подарок	TD-IDF: 0.00014
# 	Word: методический	TD-IDF: 0.00013
# 	Word: один	TD-IDF: 0.00013
# 	Word: иностранный	TD-IDF: 0.00013
# 	Word: убор	TD-IDF: 0.00013
# 	Word: сербия	TD-IDF: 0.00013
# 	Word: тематический	TD-IDF: 0.00013
# 	Word: главный	TD-IDF: 0.00013
# Top words in document: https:www.kreml.ru
# 	Word: русый	TD-IDF: 0.68483
# 	Word: инфотех	TD-IDF: 0.00069
# 	Word: загрузка	TD-IDF: 0.00037
# 	Word: фгбук	TD-IDF: 0.00033
# 	Word: кремль	TD-IDF: 0.00013
# 	Word: добраться	TD-IDF: 9e-05
# 	Word: ооо	TD-IDF: 7e-05
# 	Word: заповедник	TD-IDF: 7e-05
# 	Word: бюро	TD-IDF: 7e-05
# 	Word: магазин	TD-IDF: 6e-05
# 	Word: пресс	TD-IDF: 5e-05
# 	Word: экскурсионный	TD-IDF: 5e-05
# 	Word: наука	TD-IDF: 4e-05
# 	Word: образование	TD-IDF: 4e-05
# 	Word: историко	TD-IDF: 4e-05
# 	Word: служба	TD-IDF: 3e-05
# 	Word: правило	TD-IDF: 3e-05
# 	Word: четверг	TD-IDF: 3e-05
# 	Word: идти	TD-IDF: 2e-05
# 	Word: касса	TD-IDF: 2e-05
# 	Word: главный	TD-IDF: 2e-05
# 	Word: музейный	TD-IDF: 2e-05
# 	Word: музей	TD-IDF: 2e-05
# 	Word: московский	TD-IDF: 2e-05
# 	Word: выходной	TD-IDF: 2e-05
# 	Word: дать	TD-IDF: 1e-05
# 	Word: государственный	TD-IDF: 1e-05
# 	Word: культурный	TD-IDF: 1e-05
# 	Word: россия	TD-IDF: 1e-05
# 	Word: москва	TD-IDF: 1e-05
# 	Word: билет	TD-IDF: 1e-05
# 	Word: посетитель	TD-IDF: 1e-05
# 	Word: выставка	TD-IDF: 1e-05
# 	Word: информация	TD-IDF: 0.0
# 	Word: часы	TD-IDF: 0.0
# 	Word: работа	TD-IDF: 0.0
# Top words in document: https:akhmatova.spb.ru
# 	Word: сайта	TD-IDF: 0.01028
# 	Word: ахматов	TD-IDF: 0.00895
# 	Word: гумилев	TD-IDF: 0.00869
# 	Word: менить	TD-IDF: 0.0078
# 	Word: фонтанный	TD-IDF: 0.00694
# 	Word: гостевой	TD-IDF: 0.0051
# 	Word: учредительный	TD-IDF: 0.00485
# 	Word: бродский	TD-IDF: 0.00424
# 	Word: фотодокумент	TD-IDF: 0.00414
# 	Word: литейный	TD-IDF: 0.00325
# 	Word: волонтёрский	TD-IDF: 0.00314
# 	Word: слабовидящий	TD-IDF: 0.00294
# 	Word: подписка	TD-IDF: 0.00222
# 	Word: контрольный	TD-IDF: 0.00217
# 	Word: квартира	TD-IDF: 0.00209
# 	Word: коррупция	TD-IDF: 0.00204
# 	Word: иосиф	TD-IDF: 0.00172
# 	Word: анонс	TD-IDF: 0.00162
# 	Word: подписаться	TD-IDF: 0.00152
# 	Word: пунина	TD-IDF: 0.00152
# 	Word: благодарный	TD-IDF: 0.0015
# 	Word: анна	TD-IDF: 0.00146
# 	Word: афиша	TD-IDF: 0.00127
# 	Word: подросток	TD-IDF: 0.00117
# 	Word: лев	TD-IDF: 0.00116
# 	Word: автограф	TD-IDF: 0.00116
# 	Word: корчак	TD-IDF: 0.00113
# 	Word: сми	TD-IDF: 0.00111
# 	Word: мандельштам	TD-IDF: 0.0011
# 	Word: учитель	TD-IDF: 0.00108
# 	Word: звонить	TD-IDF: 0.00107
# 	Word: собрание	TD-IDF: 0.00106
# 	Word: зернина	TD-IDF: 0.00106
# 	Word: фонд	TD-IDF: 0.00105
# 	Word: кабинет	TD-IDF: 0.00099
# 	Word: пр	TD-IDF: 0.00094
# 	Word: таганцев	TD-IDF: 0.00092
# 	Word: сад	TD-IDF: 0.00089
# 	Word: льва гумилев	TD-IDF: 0.00087
# 	Word: 120р	TD-IDF: 0.00087
# 	Word: книга	TD-IDF: 0.00087
# 	Word: озерский	TD-IDF: 0.00086
# 	Word: 260р	TD-IDF: 0.00078
# 	Word: линия	TD-IDF: 0.00076
# 	Word: петербург	TD-IDF: 0.00073
# 	Word: шереметевский	TD-IDF: 0.00071
# 	Word: музей	TD-IDF: 0.00067
# 	Word: отзыв	TD-IDF: 0.00065
# 	Word: в рамках фестиваль	TD-IDF: 0.00064
# 	Word: пунин	TD-IDF: 0.00064
# 	Word: санкт	TD-IDF: 0.00064
# 	Word: театр	TD-IDF: 0.00064
# 	Word: мемориальный	TD-IDF: 0.0006
# 	Word: януш	TD-IDF: 0.00056
# 	Word: бродский drive	TD-IDF: 0.00055
# 	Word: американский	TD-IDF: 0.00054
# 	Word: изобразительный	TD-IDF: 0.00054
# 	Word: гумилёва	TD-IDF: 0.00053
# 	Word: ахматовский	TD-IDF: 0.00053
# 	Word: документ	TD-IDF: 0.00052
# 	Word: версия	TD-IDF: 0.00052
# 	Word: анны ахматов	TD-IDF: 0.00051
# 	Word: взрослый	TD-IDF: 0.00049
# 	Word: студент	TD-IDF: 0.00046
# 	Word: оставить	TD-IDF: 0.00045
# 	Word: вечер	TD-IDF: 0.00044
# 	Word: редкий	TD-IDF: 0.00043
# 	Word: таганцевский	TD-IDF: 0.00041
# 	Word: гумилевский	TD-IDF: 0.00041
# 	Word: александрино	TD-IDF: 0.00041
# 	Word: эрец	TD-IDF: 0.00041
# 	Word: дом	TD-IDF: 0.0004
# 	Word: бухаев	TD-IDF: 0.0004
# 	Word: разработка	TD-IDF: 0.00039
# 	Word: льготный	TD-IDF: 0.00038
# 	Word: фонтанка	TD-IDF: 0.00037
# 	Word: осипа мандельштам	TD-IDF: 0.00037
# 	Word: соццани	TD-IDF: 0.00037
# 	Word: басараб	TD-IDF: 0.00037
# 	Word: соснора	TD-IDF: 0.00037
# 	Word: ближний	TD-IDF: 0.00037
# 	Word: получать	TD-IDF: 0.00037
# 	Word: стоимость	TD-IDF: 0.00036
# 	Word: осип	TD-IDF: 0.00034
# 	Word: по стих	TD-IDF: 0.00034
# 	Word: исраэль	TD-IDF: 0.00034
# 	Word: лойко	TD-IDF: 0.00034
# 	Word: петербургский	TD-IDF: 0.00033
# 	Word: главный	TD-IDF: 0.00032
# 	Word: моде…	TD-IDF: 0.00032
# 	Word: пагава	TD-IDF: 0.00032
# 	Word: начинкина	TD-IDF: 0.00032
# 	Word: сватиковый	TD-IDF: 0.00032
# 	Word: катценштайна	TD-IDF: 0.00032
# 	Word: специальный	TD-IDF: 0.00032
# 	Word: коломенский	TD-IDF: 0.00031
# 	Word: ангесть	TD-IDF: 0.0003
# 	Word: ионенко	TD-IDF: 0.0003
# 	Word: пассионарность	TD-IDF: 0.0003
# 	Word: аронзона	TD-IDF: 0.0003
# 	Word: венцлов	TD-IDF: 0.0003
# 	Word: шереметевой	TD-IDF: 0.0003
# 	Word: 1	TD-IDF: 0.0003
# 	Word: райхштейн	TD-IDF: 0.0003
# 	Word: экспозиции	TD-IDF: 0.0003
# 	Word: роальд	TD-IDF: 0.0003
# 	Word: показать	TD-IDF: 0.00028
# 	Word: посидим…	TD-IDF: 0.00028
# 	Word: по стихотворение	TD-IDF: 0.00028
# 	Word: по поэма	TD-IDF: 0.00028
# 	Word: жердина	TD-IDF: 0.00028
# 	Word: со дня рождение	TD-IDF: 0.00028
# 	Word: презентация книга	TD-IDF: 0.00028
# 	Word: в музее льва гумилев	TD-IDF: 0.00028
# 	Word: миханди	TD-IDF: 0.00028
# 	Word: стих	TD-IDF: 0.00027
# 	Word: гордин	TD-IDF: 0.00027
# 	Word: сотрудник	TD-IDF: 0.00027
# 	Word: посетить	TD-IDF: 0.00027
# 	Word: литературный	TD-IDF: 0.00027
# 	Word: уточнять	TD-IDF: 0.00027
# 	Word: художник	TD-IDF: 0.00027
# 	Word: дюймовочка	TD-IDF: 0.00027
# 	Word: копелев	TD-IDF: 0.00027
# 	Word: поэт	TD-IDF: 0.00026
# 	Word: число	TD-IDF: 0.00026
# 	Word: резо	TD-IDF: 0.00026
# 	Word: габриадзе	TD-IDF: 0.00026
# 	Word: город…	TD-IDF: 0.00026
# 	Word: рушева	TD-IDF: 0.00026
# 	Word: карта	TD-IDF: 0.00026
# 	Word: год	TD-IDF: 0.00026
# 	Word: спектакль	TD-IDF: 0.00026
# 	Word: новость	TD-IDF: 0.00025
# 	Word: метка	TD-IDF: 0.00025
# 	Word: свой	TD-IDF: 0.00025
# 	Word: сундук	TD-IDF: 0.00025
# 	Word: событие	TD-IDF: 0.00024
# 	Word: гель	TD-IDF: 0.00024
# 	Word: кушнер	TD-IDF: 0.00024
# 	Word: сайт	TD-IDF: 0.00024
# 	Word: донна	TD-IDF: 0.00024
# 	Word: гайворонский	TD-IDF: 0.00024
# 	Word: история	TD-IDF: 0.00023
# 	Word: валей	TD-IDF: 0.00023
# 	Word: вакуленко	TD-IDF: 0.00023
# 	Word: эпштейн	TD-IDF: 0.00023
# 	Word: белан	TD-IDF: 0.00023
# 	Word: сегвея	TD-IDF: 0.00023
# 	Word: автобусная экскурсия	TD-IDF: 0.00023
# 	Word: эжена ионеско	TD-IDF: 0.00023
# 	Word: коронкевич	TD-IDF: 0.00023
# 	Word: должанский	TD-IDF: 0.00023
# 	Word: неоплаканный	TD-IDF: 0.00023
# 	Word: горенко	TD-IDF: 0.00023
# 	Word: ненарушаемый	TD-IDF: 0.00023
# 	Word: жозетта	TD-IDF: 0.00023
# 	Word: ракузина	TD-IDF: 0.00023
# 	Word: адрес	TD-IDF: 0.00023
# 	Word: судейкин	TD-IDF: 0.00023
# 	Word: нафталь	TD-IDF: 0.00023
# 	Word: ласкина	TD-IDF: 0.00023
# 	Word: шерешевский	TD-IDF: 0.00023
# 	Word: шилейко	TD-IDF: 0.00023
# 	Word: колчин	TD-IDF: 0.00022
# 	Word: быть	TD-IDF: 0.00022
# 	Word: запорожский	TD-IDF: 0.00022
# 	Word: сарай	TD-IDF: 0.00022
# 	Word: ребёнок	TD-IDF: 0.00022
# 	Word: экспозиция	TD-IDF: 0.00021
# 	Word: экскурсия	TD-IDF: 0.00021
# 	Word: николай	TD-IDF: 0.00021
# 	Word: дегтярев	TD-IDF: 0.00021
# 	Word: наоми	TD-IDF: 0.00021
# 	Word: шапито	TD-IDF: 0.00021
# 	Word: эткинд	TD-IDF: 0.00021
# 	Word: тело	TD-IDF: 0.00021
# 	Word: меню	TD-IDF: 0.0002
# 	Word: поэзия	TD-IDF: 0.0002
# 	Word: войцеховский	TD-IDF: 0.0002
# 	Word: коцюбинский	TD-IDF: 0.0002
# 	Word: лгать	TD-IDF: 0.0002
# 	Word: тоска	TD-IDF: 0.0002
# 	Word: струве	TD-IDF: 0.00019
# 	Word: поэма	TD-IDF: 0.00019
# 	Word: программа	TD-IDF: 0.00019
# 	Word: васильевский	TD-IDF: 0.00019
# 	Word: пэн	TD-IDF: 0.00019
# 	Word: островитянин	TD-IDF: 0.00019
# 	Word: аннушка	TD-IDF: 0.00019
# 	Word: неподцензурный	TD-IDF: 0.00019
# 	Word: исайя	TD-IDF: 0.00019
# 	Word: сегвеять	TD-IDF: 0.00019
# 	Word: аренс	TD-IDF: 0.00019
# 	Word: клён	TD-IDF: 0.00019
# 	Word: друговейко	TD-IDF: 0.00019
# 	Word: доджсон	TD-IDF: 0.00019
# 	Word: бугровский	TD-IDF: 0.00019
# 	Word: сигея	TD-IDF: 0.00019
# 	Word: акмеист	TD-IDF: 0.00019
# 	Word: материал	TD-IDF: 0.00019
# 	Word: одиссей	TD-IDF: 0.00019
# 	Word: билет	TD-IDF: 0.00019
# 	Word: диспут	TD-IDF: 0.00018
# 	Word: финкель	TD-IDF: 0.00018
# 	Word: хедлить	TD-IDF: 0.00018
# 	Word: распэ	TD-IDF: 0.00018
# 	Word: мурузи	TD-IDF: 0.00018
# 	Word: переснимка	TD-IDF: 0.00018
# 	Word: бесплатное приложение	TD-IDF: 0.00018
# 	Word: подъёмникмить	TD-IDF: 0.00018
# 	Word: тенью…	TD-IDF: 0.00018
# 	Word: дмитрий пахом	TD-IDF: 0.00018
# 	Word: деля…	TD-IDF: 0.00018
# 	Word: предко	TD-IDF: 0.00018
# 	Word: юлия образцов	TD-IDF: 0.00018
# 	Word: слащев	TD-IDF: 0.00018
# 	Word: некстати	TD-IDF: 0.00018
# 	Word: акмеизм	TD-IDF: 0.00018
# 	Word: вечер в музей	TD-IDF: 0.00018
# 	Word: вечер в музее льва гумилёвый	TD-IDF: 0.00018
# 	Word: поэтический вечер	TD-IDF: 0.00018
# 	Word: в саду фонтанного дом	TD-IDF: 0.00018
# 	Word: от моцарта до джаз	TD-IDF: 0.00018
# 	Word: вольтскай	TD-IDF: 0.00018
# 	Word: асенсио	TD-IDF: 0.00018
# 	Word: куик	TD-IDF: 0.00018
# 	Word: брикман	TD-IDF: 0.00018
# 	Word: фотоперевод	TD-IDF: 0.00018
# 	Word: нясь	TD-IDF: 0.00018
# 	Word: поэтический	TD-IDF: 0.00018
# 	Word: центр	TD-IDF: 0.00018
# 	Word: был…	TD-IDF: 0.00018
# 	Word: татарник	TD-IDF: 0.00018
# 	Word: анциферов	TD-IDF: 0.00018
# 	Word: энгельгардт	TD-IDF: 0.00018
# 	Word: подворотня	TD-IDF: 0.00017
# 	Word: френкель	TD-IDF: 0.00017
# 	Word: другой	TD-IDF: 0.00017
# 	Word: зощенко	TD-IDF: 0.00017
# 	Word: лурий	TD-IDF: 0.00017
# 	Word: стругацкий	TD-IDF: 0.00017
# 	Word: контакт	TD-IDF: 0.00017
# 	Word: по произведение	TD-IDF: 0.00017
# 	Word: ионеско	TD-IDF: 0.00017
# 	Word: норильск	TD-IDF: 0.00016
# 	Word: мудро	TD-IDF: 0.00016
# 	Word: милоша	TD-IDF: 0.00016
# 	Word: ури	TD-IDF: 0.00016
# 	Word: поступь	TD-IDF: 0.00016
# 	Word: вика	TD-IDF: 0.00016
# 	Word: хармс	TD-IDF: 0.00016
# 	Word: ленинградский	TD-IDF: 0.00016
# 	Word: апрель	TD-IDF: 0.00016
# 	Word: пахомов	TD-IDF: 0.00016
# 	Word: развитие	TD-IDF: 0.00015
# 	Word: саут	TD-IDF: 0.00015
# 	Word: или…	TD-IDF: 0.00015
# 	Word: бежецк	TD-IDF: 0.00015
# 	Word: войтинский	TD-IDF: 0.00015
# 	Word: иссохший	TD-IDF: 0.00015
# 	Word: шимкий	TD-IDF: 0.00015
# 	Word: непрочитанный	TD-IDF: 0.00015
# 	Word: кафельный	TD-IDF: 0.00015
# 	Word: к 125	TD-IDF: 0.00015
# 	Word: обстоятельствах…	TD-IDF: 0.00015
# 	Word: цианотипия	TD-IDF: 0.00015
# 	Word: лимбах	TD-IDF: 0.00015
# 	Word: – этый	TD-IDF: 0.00015
# 	Word: костюшкин	TD-IDF: 0.00015
# 	Word: фотограмма	TD-IDF: 0.00015
# 	Word: демкин	TD-IDF: 0.00015
# 	Word: камкина	TD-IDF: 0.00015
# 	Word: акишин	TD-IDF: 0.00015
# 	Word: гампер	TD-IDF: 0.00015
# 	Word: – поэт	TD-IDF: 0.00015
# 	Word: черняк	TD-IDF: 0.00015
# 	Word: шляпный	TD-IDF: 0.00015
# 	Word: чиж	TD-IDF: 0.00015
# 	Word: по мотив	TD-IDF: 0.00015
# 	Word: солнцев	TD-IDF: 0.00015
# 	Word: 300р	TD-IDF: 0.00015
# 	Word: жжёный	TD-IDF: 0.00015
# 	Word: мюнхгаузен	TD-IDF: 0.00015
# 	Word: аппо	TD-IDF: 0.00015
# 	Word: волосенков	TD-IDF: 0.00015
# 	Word: дядюшка	TD-IDF: 0.00015
# 	Word: лаваль	TD-IDF: 0.00015
# 	Word: 2	TD-IDF: 0.00015
# 	Word: автор	TD-IDF: 0.00015
# 	Word: который	TD-IDF: 0.00014
# 	Word: прихожая	TD-IDF: 0.00014
# 	Word: цветаев	TD-IDF: 0.00014
# 	Word: иосифа бродский	TD-IDF: 0.00014
# 	Word: жака превер	TD-IDF: 0.00014
# 	Word: николая рубцов	TD-IDF: 0.00014
# 	Word: литературные занятие	TD-IDF: 0.00014
# 	Word: топчем…	TD-IDF: 0.00014
# 	Word: в ковалевский лес	TD-IDF: 0.00014
# 	Word: исторический календарь	TD-IDF: 0.00014
# 	Word: цикл встреча	TD-IDF: 0.00014
# 	Word: с никита	TD-IDF: 0.00014
# 	Word: словами русских поэт	TD-IDF: 0.00014
# 	Word: с спб аппо	TD-IDF: 0.00014
# 	Word: ломж	TD-IDF: 0.00014
# 	Word: xv всероссийский	TD-IDF: 0.00014
# 	Word: ганса христиана андерсен	TD-IDF: 0.00014
# 	Word: богов…	TD-IDF: 0.00014
# 	Word: эшэр	TD-IDF: 0.00014
# 	Word: лесмана	TD-IDF: 0.00014
# 	Word: варбанец	TD-IDF: 0.00014
# 	Word: адреса…	TD-IDF: 0.00014
# 	Word: …тенить	TD-IDF: 0.00014
# 	Word: фонтанки…	TD-IDF: 0.00014
# 	Word: дф	TD-IDF: 0.00014
# 	Word: батрасовый	TD-IDF: 0.00014
# 	Word: ракузиналександр	TD-IDF: 0.00014
# 	Word: тоскапо	TD-IDF: 0.00014
# 	Word: сены…	TD-IDF: 0.00014
# 	Word: скобцов	TD-IDF: 0.00014
# 	Word: путешествиес	TD-IDF: 0.00014
# 	Word: надетанезрить	TD-IDF: 0.00014
# 	Word: временивый	TD-IDF: 0.00014
# 	Word: –персональный	TD-IDF: 0.00014
# 	Word: провелэтить	TD-IDF: 0.00014
# 	Word: плугомокеан	TD-IDF: 0.00014
# 	Word: поискахземный	TD-IDF: 0.00014
# 	Word: памятникавелимир	TD-IDF: 0.00014
# 	Word: шкатулкас	TD-IDF: 0.00014
# 	Word: глубиныдый	TD-IDF: 0.00014
# 	Word: фотоколлективизм	TD-IDF: 0.00014
# 	Word: истлевать	TD-IDF: 0.00014
# 	Word: романкова	TD-IDF: 0.00014
# 	Word: публь	TD-IDF: 0.00014
# 	Word: орбить	TD-IDF: 0.00014
# 	Word: верхейл	TD-IDF: 0.00014
# 	Word: учило…	TD-IDF: 0.00014
# 	Word: ленинградскаять	TD-IDF: 0.00014
# 	Word: славы…	TD-IDF: 0.00014
# 	Word: эva	TD-IDF: 0.00014
# 	Word: плахотник	TD-IDF: 0.00014
# 	Word: дутовой	TD-IDF: 0.00014
# 	Word: шлыковый	TD-IDF: 0.00014
# 	Word: гельдерман	TD-IDF: 0.00014
# 	Word: ктеры	TD-IDF: 0.00014
# 	Word: мунстарый	TD-IDF: 0.00014
# 	Word: милош	TD-IDF: 0.00014
# 	Word: биннингтон	TD-IDF: 0.00014
# 	Word: жукофф	TD-IDF: 0.00014
# 	Word: ситс	TD-IDF: 0.00014
# 	Word: тень	TD-IDF: 0.00014
# 	Word: секстет	TD-IDF: 0.00014
# 	Word: реквием	TD-IDF: 0.00014
# 	Word: лагерный	TD-IDF: 0.00013
# 	Word: алфавитный	TD-IDF: 0.00013
# 	Word: петербуржец	TD-IDF: 0.00013
# 	Word: комната	TD-IDF: 0.00013
# 	Word: террор	TD-IDF: 0.00013
# 	Word: элегия	TD-IDF: 0.00013
# 	Word: ргпу	TD-IDF: 0.00013
# 	Word: писарев	TD-IDF: 0.00013
# 	Word: свататься	TD-IDF: 0.00013
# 	Word: стукач	TD-IDF: 0.00013
# 	Word: ахапкин	TD-IDF: 0.00013
# 	Word: зинштейн	TD-IDF: 0.00013
# 	Word: доверчивость	TD-IDF: 0.00013
# 	Word: непогребенный	TD-IDF: 0.00013
# 	Word: туровский	TD-IDF: 0.00013
# 	Word: гбудо	TD-IDF: 0.00013
# 	Word: пастель	TD-IDF: 0.00013
# 	Word: коридор	TD-IDF: 0.00013
# 	Word: цапля	TD-IDF: 0.00013
# 	Word: наваждение	TD-IDF: 0.00013
# 	Word: пушкин	TD-IDF: 0.00013
# 	Word: меж	TD-IDF: 0.00013
# 	Word: ленинград	TD-IDF: 0.00012
# 	Word: вести	TD-IDF: 0.00012
# 	Word: довлат	TD-IDF: 0.00012
# 	Word: томашевский	TD-IDF: 0.00012
# 	Word: ржавый	TD-IDF: 0.00012
# 	Word: довлатов	TD-IDF: 0.00012
# 	Word: глебов	TD-IDF: 0.00012
# 	Word: работа	TD-IDF: 0.00012
# 	Word: презентация	TD-IDF: 0.00012
# 	Word: спб	TD-IDF: 0.00012
# 	Word: слово	TD-IDF: 0.00012
# 	Word: фотография	TD-IDF: 0.00012
# 	Word: экзюпери	TD-IDF: 0.00012
# 	Word: анненков	TD-IDF: 0.00012
# 	Word: жизнь	TD-IDF: 0.00012
# 	Word: елисеев	TD-IDF: 0.00012
# 	Word: гофман	TD-IDF: 0.00012
# 	Word: кровля	TD-IDF: 0.00012
# 	Word: надя	TD-IDF: 0.00012
# 	Word: беспорядок	TD-IDF: 0.00012
# 	Word: продолжительность	TD-IDF: 0.00012
# 	Word: память	TD-IDF: 0.00012
# 	Word: кузмина	TD-IDF: 0.00012
# 	Word: коринф	TD-IDF: 0.00012
# 	Word: сударь	TD-IDF: 0.00012
# 	Word: чеслав	TD-IDF: 0.00012
# 	Word: фриман	TD-IDF: 0.00012
# 	Word: литература	TD-IDF: 0.00012
# 	Word: эссеист	TD-IDF: 0.00012
# 	Word: издательство	TD-IDF: 0.00012
# 	Word: зорко	TD-IDF: 0.00012
# 	Word: бернштейн	TD-IDF: 0.00012
# 	Word: брандт	TD-IDF: 0.00012
# 	Word: светлана	TD-IDF: 0.00012
# 	Word: тбилиси	TD-IDF: 0.00011
# 	Word: арест	TD-IDF: 0.00011
# 	Word: о важный	TD-IDF: 0.00011
# 	Word: кэрролл	TD-IDF: 0.00011
# 	Word: кроличий	TD-IDF: 0.00011
# 	Word: назвать…	TD-IDF: 0.00011
# 	Word: непевный	TD-IDF: 0.00011
# 	Word: свет…	TD-IDF: 0.00011
# 	Word: пространство…	TD-IDF: 0.00011
# 	Word: мирович	TD-IDF: 0.00011
# 	Word: приснопамятный	TD-IDF: 0.00011
# 	Word: ясновое	TD-IDF: 0.00011
# 	Word: самарин	TD-IDF: 0.00011
# 	Word: баккер	TD-IDF: 0.00011
# 	Word: клюшкина	TD-IDF: 0.00011
# 	Word: гонсеровский	TD-IDF: 0.00011
# 	Word: пионтека	TD-IDF: 0.00011
# 	Word: льюис	TD-IDF: 0.00011
# 	Word: стихотворение	TD-IDF: 0.00011
# 	Word: литературовед	TD-IDF: 0.00011
# 	Word: сын	TD-IDF: 0.00011
# 	Word: выставка	TD-IDF: 0.00011
# 	Word: козырев	TD-IDF: 0.00011
# 	Word: актёр	TD-IDF: 0.00011
# 	Word: письмо	TD-IDF: 0.00011
# 	Word: чердак	TD-IDF: 0.00011
# 	Word: анне	TD-IDF: 0.00011
# 	Word: июнь	TD-IDF: 0.00011
# 	Word: достоевский	TD-IDF: 0.00011
# 	Word: филолог	TD-IDF: 0.00011
# 	Word: тырс	TD-IDF: 0.00011
# 	Word: данько	TD-IDF: 0.00011
# 	Word: наперёд	TD-IDF: 0.00011
# 	Word: караваев	TD-IDF: 0.00011
# 	Word: ддт	TD-IDF: 0.00011
# 	Word: ночлежка	TD-IDF: 0.00011
# 	Word: фотофонд	TD-IDF: 0.00011
# 	Word: шаталов	TD-IDF: 0.00011
# 	Word: эллада	TD-IDF: 0.00011
# 	Word: царскосельский	TD-IDF: 0.00011
# 	Word: кондаков	TD-IDF: 0.00011
# 	Word: даниил	TD-IDF: 0.00011
# 	Word: спасибо	TD-IDF: 0.00011
# 	Word: багаж	TD-IDF: 0.00011
# 	Word: лихачев	TD-IDF: 0.00011
# 	Word: трамвай	TD-IDF: 0.00011
# 	Word: тот	TD-IDF: 0.00011
# 	Word: текст	TD-IDF: 0.0001
# 	Word: час	TD-IDF: 0.0001
# 	Word: крылов	TD-IDF: 0.0001
# 	Word: олимп	TD-IDF: 0.0001
# 	Word: мастерский	TD-IDF: 0.0001
# 	Word: живопись	TD-IDF: 0.0001
# 	Word: график	TD-IDF: 0.0001
# 	Word: салтана	TD-IDF: 0.0001
# 	Word: решетников	TD-IDF: 0.0001
# 	Word: ведерников	TD-IDF: 0.0001
# 	Word: психоневрологический	TD-IDF: 0.0001
# 	Word: мойка	TD-IDF: 0.0001
# 	Word: жираф	TD-IDF: 0.0001
# 	Word: берггольц	TD-IDF: 0.0001
# 	Word: недоразумение	TD-IDF: 0.0001
# 	Word: хасан	TD-IDF: 0.0001
# 	Word: расстрелять	TD-IDF: 0.0001
# 	Word: щепка	TD-IDF: 0.0001
# 	Word: неразгаданный	TD-IDF: 0.0001
# 	Word: ясон	TD-IDF: 0.0001
# 	Word: перейти	TD-IDF: 0.0001
# 	Word: это	TD-IDF: 0.0001
# 	Word: для ребёнок	TD-IDF: 0.0001
# 	Word: cборник	TD-IDF: 0.0001
# 	Word: шавалиев	TD-IDF: 0.0001
# 	Word: белаковский	TD-IDF: 0.0001
# 	Word: тумина	TD-IDF: 0.0001
# 	Word: якубсон	TD-IDF: 0.0001
# 	Word: туровскай	TD-IDF: 0.0001
# 	Word: плейбек	TD-IDF: 0.0001
# 	Word: тупичок	TD-IDF: 0.0001
# 	Word: гениева	TD-IDF: 0.0001
# 	Word: творчество	TD-IDF: 0.0001
# 	Word: режиссёр	TD-IDF: 0.0001
# 	Word: переводчик	TD-IDF: 0.0001
# 	Word: хлебников	TD-IDF: 0.0001
# 	Word: очень	TD-IDF: 0.0001
# 	Word: питер	TD-IDF: 0.0001
# 	Word: предвидеть	TD-IDF: 9e-05
# 	Word: белкин	TD-IDF: 9e-05
# 	Word: подношение	TD-IDF: 9e-05
# 	Word: февраль	TD-IDF: 9e-05
# 	Word: наизусть	TD-IDF: 9e-05
# 	Word: коммунальный	TD-IDF: 9e-05
# Top words in document: http:kazan-kremlin.ru
# 	Word: татарстан	TD-IDF: 0.01548
# 	Word: благовещенский	TD-IDF: 0.01166
# 	Word: исламский	TD-IDF: 0.01119
# 	Word: пушечный	TD-IDF: 0.00994
# 	Word: государственность	TD-IDF: 0.00737
# 	Word: кремль	TD-IDF: 0.00673
# 	Word: казанский	TD-IDF: 0.00608
# 	Word: казань	TD-IDF: 0.00511
# 	Word: естественный	TD-IDF: 0.00385
# 	Word: заповедник	TD-IDF: 0.00359
# 	Word: собор	TD-IDF: 0.00323
# 	Word: эрмитаж	TD-IDF: 0.00273
# 	Word: манеж	TD-IDF: 0.00261
# 	Word: археология	TD-IDF: 0.00259
# 	Word: объявление	TD-IDF: 0.00222
# 	Word: меню	TD-IDF: 0.00164
# 	Word: история	TD-IDF: 0.00163
# 	Word: юридический	TD-IDF: 0.00161
# 	Word: семинар	TD-IDF: 0.00147
# 	Word: музей	TD-IDF: 0.00137
# 	Word: награда	TD-IDF: 0.00133
# 	Word: кул	TD-IDF: 0.00127
# 	Word: шариф	TD-IDF: 0.00114
# 	Word: мечеть	TD-IDF: 0.00112
# 	Word: отчёт	TD-IDF: 0.00106
# 	Word: татарский	TD-IDF: 0.00106
# 	Word: архитектурный	TD-IDF: 0.001
# 	Word: двор	TD-IDF: 0.00094
# 	Word: структура	TD-IDF: 0.00093
# 	Word: галерея	TD-IDF: 0.0009
# 	Word: историко	TD-IDF: 0.00084
# 	Word: архитектура	TD-IDF: 0.00083
# 	Word: рт	TD-IDF: 0.00082
# 	Word: достижение	TD-IDF: 0.00081
# 	Word: администрация	TD-IDF: 0.00081
# 	Word: шамаиль	TD-IDF: 0.00071
# 	Word: общий	TD-IDF: 0.0007
# 	Word: дополнительный	TD-IDF: 0.00069
# 	Word: событие	TD-IDF: 0.00068
# 	Word: напластование	TD-IDF: 0.00067
# 	Word: фарфория	TD-IDF: 0.00066
# 	Word: ситдиков	TD-IDF: 0.00063
# 	Word: культура	TD-IDF: 0.00061
# 	Word: независимый	TD-IDF: 0.0006
# 	Word: конференция	TD-IDF: 0.00058
# 	Word: услуга	TD-IDF: 0.00058
# 	Word: издание	TD-IDF: 0.00057
# 	Word: правило	TD-IDF: 0.00057
# 	Word: концепция	TD-IDF: 0.00057
# 	Word: зал	TD-IDF: 0.00056
# 	Word: публикация	TD-IDF: 0.00056
# 	Word: отзыв	TD-IDF: 0.00053
# 	Word: научный	TD-IDF: 0.0005
# 	Word: раскоп	TD-IDF: 0.00045
# 	Word: контакт	TD-IDF: 0.00044
# 	Word: республика	TD-IDF: 0.00043
# 	Word: центр	TD-IDF: 0.00041
# 	Word: дизайн	TD-IDF: 0.00041
# 	Word: вернуться	TD-IDF: 0.0004
# 	Word: ханский	TD-IDF: 0.0004
# 	Word: юнкерский	TD-IDF: 0.00039
# 	Word: шакир	TD-IDF: 0.00039
# 	Word: экскурсия	TD-IDF: 0.00039
# 	Word: халиков	TD-IDF: 0.00037
# 	Word: скепнер	TD-IDF: 0.00037
# 	Word: художественный	TD-IDF: 0.00036
# 	Word: выставочный	TD-IDF: 0.00036
# 	Word: оставить	TD-IDF: 0.00036
# 	Word: создание	TD-IDF: 0.00035
# 	Word: посещение	TD-IDF: 0.00034
# 	Word: деятельность	TD-IDF: 0.00034
# 	Word: новость	TD-IDF: 0.00034
# 	Word: сайт	TD-IDF: 0.00033
# 	Word: коран	TD-IDF: 0.00033
# 	Word: тайницкий	TD-IDF: 0.00032
# 	Word: башня	TD-IDF: 0.00031
# 	Word: назад	TD-IDF: 0.00031
# 	Word: анимаев	TD-IDF: 0.00031
# 	Word: мусульманка	TD-IDF: 0.0003
# 	Word: фарфоровый	TD-IDF: 0.0003
# 	Word: передвижник	TD-IDF: 0.0003
# 	Word: выставка	TD-IDF: 0.0003
# 	Word: программа	TD-IDF: 0.00029
# 	Word: зиля	TD-IDF: 0.00029
# 	Word: разработка	TD-IDF: 0.00028
# 	Word: рубль	TD-IDF: 0.00028
# 	Word: государственный	TD-IDF: 0.00028
# 	Word: валеев	TD-IDF: 0.00027
# 	Word: ханство	TD-IDF: 0.00027
# 	Word: мусульманский	TD-IDF: 0.00027
# 	Word: каллиграфия	TD-IDF: 0.00026
# 	Word: сююмбик	TD-IDF: 0.00026
# 	Word: этери	TD-IDF: 0.00026
# 	Word: татарин	TD-IDF: 0.00025
# 	Word: фарфор	TD-IDF: 0.00025
# 	Word: оркестр	TD-IDF: 0.00025
# 	Word: эрмитажный	TD-IDF: 0.00024
# 	Word: работа	TD-IDF: 0.00024
# 	Word: ризалит	TD-IDF: 0.00023
# 	Word: фанфара	TD-IDF: 0.00023
# 	Word: оценка	TD-IDF: 0.00023
# 	Word: эбра	TD-IDF: 0.00023
# 	Word: загс	TD-IDF: 0.00022
# 	Word: барудить	TD-IDF: 0.00022
# 	Word: богородицкий	TD-IDF: 0.00022
# 	Word: мусульманин	TD-IDF: 0.00022
# 	Word: информация	TD-IDF: 0.00022
# 	Word: старков	TD-IDF: 0.00022
# 	Word: микроскоп	TD-IDF: 0.00022
# 	Word: фоамиран	TD-IDF: 0.00021
# 	Word: седмиезерный	TD-IDF: 0.00021
# 	Word: проездной	TD-IDF: 0.00021
# 	Word: сююмбек	TD-IDF: 0.0002
# 	Word: архиерейский	TD-IDF: 0.0002
# 	Word: православный	TD-IDF: 0.0002
# 	Word: рабеа	TD-IDF: 0.0002
# 	Word: забировой	TD-IDF: 0.0002
# 	Word: казанец	TD-IDF: 0.00019
# 	Word: прясло	TD-IDF: 0.00019
# 	Word: домонгольский	TD-IDF: 0.00019
# 	Word: шарифуллин	TD-IDF: 0.00019
# 	Word: дробный	TD-IDF: 0.00019
# 	Word: мажоретка	TD-IDF: 0.00018
# 	Word: ислам	TD-IDF: 0.00018
# 	Word: казанка	TD-IDF: 0.00018
# 	Word: археологический	TD-IDF: 0.00018
# 	Word: мухаметзянов	TD-IDF: 0.00018
# 	Word: хохломской	TD-IDF: 0.00018
# 	Word: ярус	TD-IDF: 0.00017
# 	Word: луповский	TD-IDF: 0.00017
# 	Word: кроноцкий	TD-IDF: 0.00017
# 	Word: карта	TD-IDF: 0.00017
# 	Word: саудовский	TD-IDF: 0.00017
# 	Word: шоу	TD-IDF: 0.00016
# 	Word: икона	TD-IDF: 0.00016
# 	Word: джамал	TD-IDF: 0.00016
# 	Word: городище	TD-IDF: 0.00016
# 	Word: хохлом	TD-IDF: 0.00016
# 	Word: карниз	TD-IDF: 0.00016
# 	Word: остаток	TD-IDF: 0.00016
# 	Word: илугдин	TD-IDF: 0.00016
# 	Word: ii место	TD-IDF: 0.00016
# 	Word: профилировать	TD-IDF: 0.00016
# 	Word: хузин	TD-IDF: 0.00016
# 	Word: кремлёвский	TD-IDF: 0.00016
# 	Word: присутственный	TD-IDF: 0.00015
# 	Word: глазурь	TD-IDF: 0.00015
# 	Word: мавр	TD-IDF: 0.00015
# 	Word: прометей	TD-IDF: 0.00015
# 	Word: кирпичный	TD-IDF: 0.00015
# 	Word: спасо	TD-IDF: 0.00015
# 	Word: преображенский	TD-IDF: 0.00015
# 	Word: асный	TD-IDF: 0.00015
# 	Word: айвар	TD-IDF: 0.00015
# 	Word: птм	TD-IDF: 0.00015
# 	Word: iii место	TD-IDF: 0.00015
# 	Word: рустам	TD-IDF: 0.00015
# 	Word: квеста	TD-IDF: 0.00014
# 	Word: феврония	TD-IDF: 0.00014
# 	Word: наличник	TD-IDF: 0.00014
# 	Word: крио	TD-IDF: 0.00014
# 	Word: кровля	TD-IDF: 0.00014
# 	Word: божий	TD-IDF: 0.00014
# 	Word: год	TD-IDF: 0.00014
# 	Word: губернаторский	TD-IDF: 0.00014
# 	Word: заповедный	TD-IDF: 0.00014
# 	Word: чулпан	TD-IDF: 0.00014
# 	Word: тукать	TD-IDF: 0.00014
# 	Word: муфтий	TD-IDF: 0.00014
# 	Word: имам	TD-IDF: 0.00014
# 	Word: неопалимый	TD-IDF: 0.00014
# 	Word: подклет	TD-IDF: 0.00014
# 	Word: поволжье	TD-IDF: 0.00014
# 	Word: аравия	TD-IDF: 0.00014
# 	Word: лекция	TD-IDF: 0.00013
# 	Word: белокаменный	TD-IDF: 0.00013
# 	Word: красоты…	TD-IDF: 0.00013
# 	Word: ураз	TD-IDF: 0.00013
# 	Word: барабанщица	TD-IDF: 0.00013
# 	Word: батта	TD-IDF: 0.00013
# 	Word: тасср	TD-IDF: 0.00013
# 	Word: баннерный	TD-IDF: 0.00013
# 	Word: радик	TD-IDF: 0.00013
# 	Word: кфу	TD-IDF: 0.00013
# 	Word: ринат	TD-IDF: 0.00013
# 	Word: палеонтологический	TD-IDF: 0.00013
# 	Word: курамшина	TD-IDF: 0.00013
# 	Word: стоимость	TD-IDF: 0.00013
# 	Word: трапезный	TD-IDF: 0.00013
# 	Word: билет	TD-IDF: 0.00013
# 	Word: благодарственный	TD-IDF: 0.00013
# 	Word: занятие	TD-IDF: 0.00013
# 	Word: турок	TD-IDF: 0.00013
# 	Word: фестиваль	TD-IDF: 0.00013
# 	Word: мбоу	TD-IDF: 0.00013
# 	Word: спасский	TD-IDF: 0.00012
# 	Word: галимджан	TD-IDF: 0.00012
# 	Word: хадиева	TD-IDF: 0.00012
# 	Word: варалло	TD-IDF: 0.00012
# 	Word: батт	TD-IDF: 0.00012
# 	Word: реставро	TD-IDF: 0.00012
# 	Word: ксифактин	TD-IDF: 0.00012
# 	Word: мөхәммәд	TD-IDF: 0.00012
# 	Word: росарио	TD-IDF: 0.00012
# 	Word: 150рубль	TD-IDF: 0.00012
# 	Word: кабанский	TD-IDF: 0.00012
# 	Word: стратиграфически	TD-IDF: 0.00012
# 	Word: чудотворец	TD-IDF: 0.00012
# 	Word: галеев	TD-IDF: 0.00012
# 	Word: монастырь	TD-IDF: 0.00012
# 	Word: товарный	TD-IDF: 0.00012
# 	Word: купина	TD-IDF: 0.00012
# 	Word: посетитель	TD-IDF: 0.00012
# 	Word: бианка	TD-IDF: 0.00012
# 	Word: новогодний	TD-IDF: 0.00012
# 	Word: татарка	TD-IDF: 0.00012
# 	Word: минтимер	TD-IDF: 0.00012
# 	Word: шаймиев	TD-IDF: 0.00012
# 	Word: фундамент	TD-IDF: 0.00011
# 	Word: ермоген	TD-IDF: 0.00011
# 	Word: байрам	TD-IDF: 0.00011
# 	Word: зилантов	TD-IDF: 0.00011
# 	Word: шамаилей	TD-IDF: 0.00011
# 	Word: динозавр	TD-IDF: 0.00011
# 	Word: пристроить	TD-IDF: 0.00011
# 	Word: арабский	TD-IDF: 0.00011
# 	Word: турецкий	TD-IDF: 0.00011
# 	Word: часы	TD-IDF: 0.00011
# 	Word: декада	TD-IDF: 0.00011
# 	Word: уен	TD-IDF: 0.00011
# 	Word: мёррей	TD-IDF: 0.00011
# 	Word: рамазан	TD-IDF: 0.00011
# 	Word: зиганшин	TD-IDF: 0.00011
# 	Word: мухаммад	TD-IDF: 0.00011
# 	Word: булгарский	TD-IDF: 0.00011
# 	Word: ирфан	TD-IDF: 0.00011
# 	Word: курешить	TD-IDF: 0.00011
# 	Word: алькибасить	TD-IDF: 0.00011
# 	Word: забир	TD-IDF: 0.00011
# 	Word: мехтереть	TD-IDF: 0.00011
# 	Word: кебасить	TD-IDF: 0.00011
# 	Word: рашид	TD-IDF: 0.00011
# 	Word: состояться	TD-IDF: 0.00011
# 	Word: класс	TD-IDF: 0.00011
# 	Word: каменный	TD-IDF: 0.00011
# 	Word: веков…	TD-IDF: 0.00011
# 	Word: 100рубль	TD-IDF: 0.00011
# 	Word: руст	TD-IDF: 0.00011
# 	Word: полимерный	TD-IDF: 0.00011
# 	Word: джазовый	TD-IDF: 0.0001
# 	Word: аль	TD-IDF: 0.0001
# 	Word: пилястр	TD-IDF: 0.0001
# 	Word: планета	TD-IDF: 0.0001
# 	Word: лекторий	TD-IDF: 0.0001
# 	Word: золотоордынский	TD-IDF: 0.0001
# 	Word: прямоугольный	TD-IDF: 0.0001
# 	Word: джулиани	TD-IDF: 0.0001
# 	Word: фукс	TD-IDF: 0.0001
# 	Word: мастер	TD-IDF: 0.0001
# 	Word: предварительный	TD-IDF: 0.0001
# 	Word: мостовый	TD-IDF: 0.0001
# 	Word: вязь	TD-IDF: 0.0001
# 	Word: арочный	TD-IDF: 0.0001
# 	Word: татарстанский	TD-IDF: 0.0001
# 	Word: исхаков	TD-IDF: 0.0001
# 	Word: роналда	TD-IDF: 0.0001
# 	Word: рустовать	TD-IDF: 0.0001
# 	Word: караульня	TD-IDF: 0.0001
# 	Word: татинвестгражданпроект	TD-IDF: 0.0001
# 	Word: бериашвили	TD-IDF: 0.0001
# 	Word: шестистолпный	TD-IDF: 0.0001
# 	Word: гауптвахта	TD-IDF: 0.0001
# 	Word: духов	TD-IDF: 0.0001
# 	Word: холм	TD-IDF: 0.0001
# 	Word: примыкать	TD-IDF: 0.0001
# 	Word: командорский	TD-IDF: 0.0001
# 	Word: минарет	TD-IDF: 0.0001
# 	Word: рустем	TD-IDF: 0.0001
# 	Word: стена	TD-IDF: 0.0001
# 	Word: лопатка	TD-IDF: 0.0001
# 	Word: четверик	TD-IDF: 0.0001
# 	Word: путешествие	TD-IDF: 0.0001
# 	Word: ширять	TD-IDF: 0.0001
# 	Word: тамин	TD-IDF: 0.0001
# 	Word: гарделеген	TD-IDF: 0.0001
# 	Word: цветошник	TD-IDF: 0.0001
# 	Word: перестраница	TD-IDF: 0.0001
# 	Word: контрналичник	TD-IDF: 0.0001
# 	Word: сандрик	TD-IDF: 0.0001
# 	Word: вейра	TD-IDF: 0.0001
# 	Word: гаязов	TD-IDF: 0.0001
# 	Word: тезицкий	TD-IDF: 0.0001
# 	Word: шавохина	TD-IDF: 0.0001
# 	Word: муралеев	TD-IDF: 0.0001
# 	Word: хан	TD-IDF: 0.0001
# 	Word: айдаров	TD-IDF: 0.0001
# 	Word: антарктида	TD-IDF: 0.0001
# 	Word: лёд	TD-IDF: 9e-05
# 	Word: крещенский	TD-IDF: 9e-05
# 	Word: хазрат	TD-IDF: 9e-05
# 	Word: пакистан	TD-IDF: 9e-05
# 	Word: похвала	TD-IDF: 9e-05
# 	Word: служение	TD-IDF: 9e-05
# 	Word: который	TD-IDF: 9e-05
# 	Word: территория	TD-IDF: 9e-05
# 	Word: заступница	TD-IDF: 9e-05
# 	Word: шэрон	TD-IDF: 9e-05
# 	Word: дымковский	TD-IDF: 9e-05
# 	Word: пилигрим	TD-IDF: 9e-05
# 	Word: марджани	TD-IDF: 9e-05
# 	Word: траншея	TD-IDF: 9e-05
# 	Word: лотерея	TD-IDF: 9e-05
# 	Word: век	TD-IDF: 9e-05
# 	Word: куфь	TD-IDF: 9e-05
# 	Word: приглашает…	TD-IDF: 9e-05
# 	Word: биктимиров	TD-IDF: 9e-05
# 	Word: сандецкий	TD-IDF: 9e-05
# 	Word: валиуллин	TD-IDF: 9e-05
# 	Word: пилон	TD-IDF: 9e-05
# 	Word: гурий	TD-IDF: 9e-05
# 	Word: трио	TD-IDF: 9e-05
# 	Word: день	TD-IDF: 9e-05
# 	Word: июнь	TD-IDF: 9e-05
# 	Word: приволжский	TD-IDF: 9e-05
# 	Word: раифский	TD-IDF: 9e-05
# 	Word: макдоналд	TD-IDF: 9e-05
# 	Word: билярский	TD-IDF: 9e-05
# 	Word: музыка	TD-IDF: 9e-05
# 	Word: храм	TD-IDF: 9e-05
# 	Word: батарейка	TD-IDF: 9e-05
# 	Word: минниханов	TD-IDF: 9e-05
# 	Word: айгуль	TD-IDF: 9e-05
# 	Word: раскопка	TD-IDF: 9e-05
# 	Word: эксперимент	TD-IDF: 9e-05
# 	Word: слой	TD-IDF: 9e-05
# 	Word: джаз	TD-IDF: 9e-05
# 	Word: салим	TD-IDF: 9e-05
# 	Word: пройти	TD-IDF: 9e-05
# 	Word: фея	TD-IDF: 9e-05
# 	Word: ров	TD-IDF: 9e-05
# 	Word: ящер	TD-IDF: 9e-05
# 	Word: преходящий	TD-IDF: 9e-05
# 	Word: зельфира	TD-IDF: 9e-05
# 	Word: концерт	TD-IDF: 9e-05
# 	Word: живу…	TD-IDF: 9e-05
# 	Word: ковреин	TD-IDF: 9e-05
# 	Word: кропин	TD-IDF: 9e-05
# 	Word: ладомиро	TD-IDF: 9e-05
# 	Word: калаганов	TD-IDF: 9e-05
# 	Word: барутчугиля	TD-IDF: 9e-05
# 	Word: кисв	TD-IDF: 9e-05
# 	Word: жукамо	TD-IDF: 9e-05
# 	Word: челны	TD-IDF: 9e-05
# 	Word: лобачевский	TD-IDF: 8e-05
# 	Word: каллиграф	TD-IDF: 8e-05
# 	Word: мина	TD-IDF: 8e-05
# 	Word: фасад	TD-IDF: 8e-05
# 	Word: перекрыть	TD-IDF: 8e-05
# 	Word: автобусный	TD-IDF: 8e-05
# 	Word: третьяковский	TD-IDF: 8e-05
# 	Word: пруссия	TD-IDF: 8e-05
# 	Word: вещество	TD-IDF: 8e-05
# 	Word: двухэтажный	TD-IDF: 8e-05
# 	Word: аудиовизуальный	TD-IDF: 8e-05
# 	Word: булат	TD-IDF: 8e-05
# 	Word: турында	TD-IDF: 8e-05
# 	Word: миннихан	TD-IDF: 8e-05
# 	Word: трехцентровой	TD-IDF: 8e-05
# 	Word: мисыр	TD-IDF: 8e-05
# 	Word: нигер	TD-IDF: 8e-05
# 	Word: галантерейный	TD-IDF: 8e-05
# 	Word: любви…	TD-IDF: 8e-05
# 	Word: кизический	TD-IDF: 8e-05
# 	Word: фарфорист	TD-IDF: 8e-05
# 	Word: голубевод	TD-IDF: 8e-05
# 	Word: мекка	TD-IDF: 8e-05
# 	Word: вала	TD-IDF: 8e-05
# 	Word: каренин	TD-IDF: 8e-05
# 	Word: медуза	TD-IDF: 8e-05
# 	Word: трегулов	TD-IDF: 8e-05
# 	Word: обманка	TD-IDF: 8e-05
# 	Word: писцовый	TD-IDF: 8e-05
# 	Word: богородица	TD-IDF: 8e-05
# 	Word: тульский	TD-IDF: 8e-05
# 	Word: крепость	TD-IDF: 8e-05
# 	Word: бауман	TD-IDF: 8e-05
# 	Word: святыня	TD-IDF: 8e-05
# 	Word: апсида	TD-IDF: 8e-05
# 	Word: медресе	TD-IDF: 8e-05
# 	Word: шурф	TD-IDF: 8e-05
# 	Word: динозаврик	TD-IDF: 8e-05
# 	Word: винегрет	TD-IDF: 8e-05
# 	Word: саттаров	TD-IDF: 8e-05
# 	Word: габдулла	TD-IDF: 8e-05
# 	Word: набиуллин	TD-IDF: 8e-05
# 	Word: древнерусский	TD-IDF: 8e-05
# 	Word: подоконный	TD-IDF: 8e-05
# 	Word: салих	TD-IDF: 8e-05
# 	Word: добровольчество	TD-IDF: 8e-05
# 	Word: бастьен	TD-IDF: 8e-05
# 	Word: республиканский	TD-IDF: 8e-05
# 	Word: корпус	TD-IDF: 8e-05
# 	Word: северный	TD-IDF: 8e-05
# 	Word: февраль	TD-IDF: 8e-05
# 	Word: один	TD-IDF: 8e-05
# 	Word: художник	TD-IDF: 8e-05
# 	Word: дикий	TD-IDF: 8e-05
# 	Word: прозрачный	TD-IDF: 8e-05
# 	Word: проём	TD-IDF: 8e-05
# 	Word: османский	TD-IDF: 8e-05
# 	Word: лекционный	TD-IDF: 8e-05
# 	Word: постройка	TD-IDF: 8e-05
# 	Word: каллиграфический	TD-IDF: 8e-05
# 	Word: пастырь	TD-IDF: 8e-05
# 	Word: кубок	TD-IDF: 7e-05
# 	Word: орда	TD-IDF: 7e-05
# 	Word: вечерок	TD-IDF: 7e-05
# 	Word: планет	TD-IDF: 7e-05
# 	Word: град	TD-IDF: 7e-05
# 	Word: замковый	TD-IDF: 7e-05
# 	Word: питомец	TD-IDF: 7e-05
# 	Word: матч	TD-IDF: 7e-05
# 	Word: сламс	TD-IDF: 7e-05
# 	Word: небе…	TD-IDF: 7e-05
# 	Word: нурсултан	TD-IDF: 7e-05
# 	Word: пожужжать…	TD-IDF: 7e-05
# 	Word: аналар	TD-IDF: 7e-05
# 	Word: сөйләшик	TD-IDF: 7e-05
# 	Word: забвенья…	TD-IDF: 7e-05
# 	Word: татарстана…	TD-IDF: 7e-05
# 	Word: энергопартнёр	TD-IDF: 7e-05
# 	Word: бочат	TD-IDF: 7e-05
# 	Word: вальмовый	TD-IDF: 7e-05
# 	Word: абдрахманов	TD-IDF: 7e-05
# 	Word: эрмитажказань	TD-IDF: 7e-05
# 	Word: передвижникивказань	TD-IDF: 7e-05
# 	Word: утверждение…	TD-IDF: 7e-05
# 	Word: максудить	TD-IDF: 7e-05
# 	Word: килевидный	TD-IDF: 7e-05
# 	Word: мухамадий	TD-IDF: 7e-05
# 	Word: межлаук	TD-IDF: 7e-05
# 	Word: пятиграть	TD-IDF: 7e-05
# 	Word: мадоу	TD-IDF: 7e-05
# 	Word: отложение	TD-IDF: 7e-05
# 	Word: торец	TD-IDF: 7e-05
# 	Word: сайдашева	TD-IDF: 7e-05
# 	Word: гульбище	TD-IDF: 7e-05
# 	Word: выявить	TD-IDF: 7e-05
# 	Word: занимательный	TD-IDF: 7e-05
# 	Word: взрослый	TD-IDF: 7e-05
# 	Word: свадьба	TD-IDF: 7e-05
# 	Word: инклюзия	TD-IDF: 7e-05
# 	Word: валик	TD-IDF: 7e-05
# 	Word: волжский	TD-IDF: 7e-05
# 	Word: юго	TD-IDF: 7e-05
# 	Word: творческий	TD-IDF: 7e-05
# 	Word: невьянский	TD-IDF: 7e-05
# 	Word: жиганов	TD-IDF: 7e-05
# 	Word: горнозаводский	TD-IDF: 7e-05
# 	Word: консисторский	TD-IDF: 7e-05
# 	Word: леван	TD-IDF: 7e-05
# 	Word: мухаммед	TD-IDF: 7e-05
# 	Word: церковь	TD-IDF: 7e-05
# 	Word: турция	TD-IDF: 7e-05
# 	Word: ледниковый	TD-IDF: 7e-05
# 	Word: н2о	TD-IDF: 7e-05
# 	Word: хикмет	TD-IDF: 7e-05
# 	Word: болгаро	TD-IDF: 7e-05
# 	Word: мухаметзян	TD-IDF: 7e-05
# 	Word: түгәрәк	TD-IDF: 7e-05
# 	Word: рамка	TD-IDF: 7e-05
# 	Word: идентификатор	TD-IDF: 7e-05
# 	Word: подплывать	TD-IDF: 7e-05
# 	Word: зилант	TD-IDF: 7e-05
# 	Word: консистория	TD-IDF: 7e-05
# 	Word: сажный	TD-IDF: 7e-05
# 	Word: барс	TD-IDF: 7e-05
# 	Word: узнать	TD-IDF: 7e-05
# 	Word: россия	TD-IDF: 7e-05
# 	Word: свой	TD-IDF: 7e-05
# 	Word: древний	TD-IDF: 7e-05
# 	Word: демидов	TD-IDF: 7e-05
# 	Word: укрепление	TD-IDF: 7e-05
# 	Word: невооружённый	TD-IDF: 7e-05
# 	Word: приглашать	TD-IDF: 7e-05
# ...
# 	Word: кб	TD-IDF: 0.00658
# 	Word: августа ть	TD-IDF: 0.00649
# 	Word: мб	TD-IDF: 0.00614
# 	Word: краеведческий	TD-IDF: 0.00543
# 	Word: ново	TD-IDF: 0.00534
# 	Word: новосибирский	TD-IDF: 0.00481
# 	Word: контактность	TD-IDF: 0.00475
# 	Word: госзадание	TD-IDF: 0.00444
# 	Word: нсо	TD-IDF: 0.0043
# 	Word: нгкм	TD-IDF: 0.00391
# 	Word: вокзальный	TD-IDF: 0.00386
# 	Word: и контора	TD-IDF: 0.0038
# 	Word: фхд	TD-IDF: 0.0038
# 	Word: россия —	TD-IDF: 0.00342
# 	Word: медеплавильный	TD-IDF: 0.00337
# 	Word: пфхд	TD-IDF: 0.00337
# 	Word: подписаться	TD-IDF: 0.00293
# 	Word: заказать	TD-IDF: 0.00287
# 	Word: олимпийский	TD-IDF: 0.00285
# 	Word: сузуна	TD-IDF: 0.00285
# 	Word: о вуз	TD-IDF: 0.00285
# 	Word: подарочный	TD-IDF: 0.00241
# 	Word: августа по 12	TD-IDF: 0.00238
# 	Word: 8 август	TD-IDF: 0.00235
# 	Word: есть ть	TD-IDF: 0.00235
# 	Word: и график	TD-IDF: 0.00205
# 	Word: по суббота	TD-IDF: 0.00205
# 	Word: в касса	TD-IDF: 0.00205
# 	Word: соцсеть	TD-IDF: 0.00202
# 	Word: вы мочь	TD-IDF: 0.002
# 	Word: в музей	TD-IDF: 0.00199
# 	Word: тело	TD-IDF: 0.00197
# 	Word: незав	TD-IDF: 0.00195
# 	Word: рассылка	TD-IDF: 0.0019
# 	Word: старощука	TD-IDF: 0.0019
# 	Word: в древность	TD-IDF: 0.0019
# 	Word: июля по 19	TD-IDF: 0.0019
# 	Word: от великое	TD-IDF: 0.0019
# 	Word: к великий	TD-IDF: 0.0019
# 	Word: вакансия	TD-IDF: 0.00186
# 	Word: в здание	TD-IDF: 0.0018
# 	Word: сертификат	TD-IDF: 0.00179
# 	Word: магистраль	TD-IDF: 0.00176
# 	Word: балл	TD-IDF: 0.00169
# 	Word: у вас	TD-IDF: 0.00168
# 	Word: колода	TD-IDF: 0.00168
# 	Word: ый	TD-IDF: 0.00165
# 	Word: льгота	TD-IDF: 0.00163
# 	Word: а такж	TD-IDF: 0.0016
# 	Word: к сожаление	TD-IDF: 0.00156
# 	Word: к музейный	TD-IDF: 0.00156
# 	Word: хх век	TD-IDF: 0.00156
# 	Word: паук	TD-IDF: 0.00146
# 	Word: сибиряк	TD-IDF: 0.00146
# 	Word: в состав	TD-IDF: 0.00146
# 	Word: природа	TD-IDF: 0.00144
# 	Word: тропик	TD-IDF: 0.00143
# 	Word: элия	TD-IDF: 0.00143
# 	Word: белютина	TD-IDF: 0.00143
# 	Word: до приход	TD-IDF: 0.00143
# 	Word: от освоение	TD-IDF: 0.00143
# 	Word: и шкатулка	TD-IDF: 0.00143
# 	Word: ломенкова	TD-IDF: 0.00143
# 	Word: в мтк	TD-IDF: 0.00143
# 	Word: с плый	TD-IDF: 0.00143
# 	Word: в 08	TD-IDF: 0.00143
# 	Word: в новосибирский	TD-IDF: 0.00143
# 	Word: loading	TD-IDF: 0.00143
# 	Word: и корректно	TD-IDF: 0.00143
# 	Word: о целесообразность	TD-IDF: 0.00143
# 	Word: на факультет	TD-IDF: 0.00143
# 	Word: за ответ	TD-IDF: 0.00143
# 	Word: и согласование	TD-IDF: 0.00143
# 	Word: интересуют ть	TD-IDF: 0.00143
# 	Word: и лампа	TD-IDF: 0.00143
# 	Word: и детальный	TD-IDF: 0.00143
# 	Word: их сохранность	TD-IDF: 0.00143
# 	Word: в служба	TD-IDF: 0.00143
# 	Word: на зуб	TD-IDF: 0.00143
# 	Word: со 2ий	TD-IDF: 0.00143
# 	Word: и удача	TD-IDF: 0.00143
# 	Word: д по заказ	TD-IDF: 0.00143
# 	Word: я приобрести	TD-IDF: 0.00143
# 	Word: я в курганский	TD-IDF: 0.00143
# 	Word: не увидеть	TD-IDF: 0.00143
# 	Word: и есть ть	TD-IDF: 0.00143
# 	Word: и пенсионеров —	TD-IDF: 0.00143
# 	Word: на сменный	TD-IDF: 0.00143
# 	Word: и варьироваться	TD-IDF: 0.00143
# 	Word: от выставка	TD-IDF: 0.00143
# 	Word: обслуживания —	TD-IDF: 0.00143
# 	Word: природы —	TD-IDF: 0.00143
# 	Word: о покупка	TD-IDF: 0.00143
# 	Word: их в касса	TD-IDF: 0.00143
# 	Word: вы хотели б	TD-IDF: 0.00143
# 	Word: нивита	TD-IDF: 0.00143
# 	Word: сгупс	TD-IDF: 0.00143
# 	Word: о интересовать	TD-IDF: 0.00143
# 	Word: с 1932	TD-IDF: 0.00143
# 	Word: то время…	TD-IDF: 0.00143
# 	Word: на доступ	TD-IDF: 0.00143
# 	Word: в венгеровский	TD-IDF: 0.00143
# 	Word: крячкова	TD-IDF: 0.00143
# 	Word: оценивать	TD-IDF: 0.00139
# 	Word: усадьба	TD-IDF: 0.00139
# 	Word: гаук	TD-IDF: 0.00137
# 	Word: в сибирь	TD-IDF: 0.00137
# 	Word: из фонд	TD-IDF: 0.00137
# 	Word: на первое	TD-IDF: 0.00137
# 	Word: плотина	TD-IDF: 0.00134
# 	Word: музей	TD-IDF: 0.00125
# 	Word: стимпанк	TD-IDF: 0.00123
# 	Word: оленеводство	TD-IDF: 0.00123
# 	Word: сибирь	TD-IDF: 0.00121
# 	Word: и становление	TD-IDF: 0.00117
# 	Word: с активный	TD-IDF: 0.00117
# 	Word: 15 август	TD-IDF: 0.00117
# 	Word: я учиться	TD-IDF: 0.00117
# 	Word: нужно ть	TD-IDF: 0.00117
# 	Word: я журналист	TD-IDF: 0.00117
# 	Word: и соответствующий	TD-IDF: 0.00117
# 	Word: с отдел	TD-IDF: 0.00117
# 	Word: и подготовить	TD-IDF: 0.00117
# 	Word: на посещение	TD-IDF: 0.00117
# 	Word: с праздник	TD-IDF: 0.00117
# 	Word: могу ть	TD-IDF: 0.00117
# 	Word: не осуществляться	TD-IDF: 0.00117
# 	Word: на сайт	TD-IDF: 0.00117
# 	Word: и можный	TD-IDF: 0.00117
# 	Word: и сколько	TD-IDF: 0.00117
# 	Word: в час	TD-IDF: 0.00117
# 	Word: и льгота	TD-IDF: 0.00117
# 	Word: на группа	TD-IDF: 0.00117
# 	Word: по постоянный	TD-IDF: 0.00117
# 	Word: в военный	TD-IDF: 0.00117
# 	Word: и отправить	TD-IDF: 0.00117
# 	Word: о музейный	TD-IDF: 0.00117
# 	Word: с обширный	TD-IDF: 0.00117
# 	Word: тартас	TD-IDF: 0.00117
# 	Word: сузунский	TD-IDF: 0.00117
# 	Word: начала хха	TD-IDF: 0.00117
# 	Word: шаманизм	TD-IDF: 0.00112
# 	Word: якут	TD-IDF: 0.00104
# 	Word: максимальный	TD-IDF: 0.00104
# 	Word: в настоящий	TD-IDF: 0.00103
# 	Word: анимизм	TD-IDF: 0.00103
# 	Word: в экскурсионный	TD-IDF: 0.00103
# 	Word: за собой	TD-IDF: 0.00103
# 	Word: и мна	TD-IDF: 0.00103
# 	Word: и определить	TD-IDF: 0.00103
# 	Word: пжл	TD-IDF: 0.00103
# 	Word: 2ой	TD-IDF: 0.00103
# 	Word: стоимость —	TD-IDF: 0.00103
# 	Word: в другий	TD-IDF: 0.00103
# 	Word: на каждовать	TD-IDF: 0.00103
# 	Word: экспозиции —	TD-IDF: 0.00103
# 	Word: в зависимость	TD-IDF: 0.00103
# 	Word: то этый	TD-IDF: 0.00103
# 	Word: в база	TD-IDF: 0.00103
# 	Word: с двумить	TD-IDF: 0.00103
# 	Word: на река	TD-IDF: 0.00103
# 	Word: по проект	TD-IDF: 0.00103
# 	Word: и музейный	TD-IDF: 0.00103
# 	Word: тунгуска	TD-IDF: 0.00103
# 	Word: кета	TD-IDF: 0.00103
# 	Word: и другий	TD-IDF: 0.00102
# 	Word: здравствовать	TD-IDF: 0.00099
# 	Word: до 18−00	TD-IDF: 0.00095
# 	Word: к кандидат	TD-IDF: 0.00095
# 	Word: с администратор	TD-IDF: 0.00095
# 	Word: о планировать	TD-IDF: 0.00095
# 	Word: августа по 30	TD-IDF: 0.00095
# 	Word: в сузун	TD-IDF: 0.00095
# 	Word: и верование	TD-IDF: 0.00095
# 	Word: барсуковский	TD-IDF: 0.00095
# 	Word: от начала хха	TD-IDF: 0.00095
# 	Word: полуавтоматический	TD-IDF: 0.00095
# 	Word: экспонат —	TD-IDF: 0.00095
# 	Word: в 180	TD-IDF: 0.00095
# 	Word: в 1764 г	TD-IDF: 0.00095
# 	Word: и монетный	TD-IDF: 0.00095
# 	Word: а с 1766	TD-IDF: 0.00095
# 	Word: по 1782 г	TD-IDF: 0.00095
# 	Word: метлина	TD-IDF: 0.00095
# 	Word: в 1908	TD-IDF: 0.00095
# 	Word: мы восстановить	TD-IDF: 0.00095
# 	Word: и до нануть	TD-IDF: 0.00095
# 	Word: в отреставрировать	TD-IDF: 0.00095
# 	Word: новосибирска —	TD-IDF: 0.00095
# 	Word: их численность	TD-IDF: 0.00095
# 	Word: завод	TD-IDF: 0.00095
# 	Word: вт	TD-IDF: 0.00092
# 	Word: х —	TD-IDF: 0.00092
# 	Word: xx век	TD-IDF: 0.00092
# 	Word: в игровой	TD-IDF: 0.00092
# 	Word: в продажа	TD-IDF: 0.00092
# 	Word: государственый	TD-IDF: 0.00092
# 	Word: в каждом	TD-IDF: 0.00092
# 	Word: в таком	TD-IDF: 0.00092
# 	Word: вы смочь	TD-IDF: 0.00092
# 	Word: с сотрудник	TD-IDF: 0.00092
# 	Word: на этота	TD-IDF: 0.00092
# 	Word: и ести	TD-IDF: 0.00092
# 	Word: с ребёнок	TD-IDF: 0.00092
# 	Word: не нужный	TD-IDF: 0.00092
# 	Word: но ести	TD-IDF: 0.00092
# 	Word: тунгус	TD-IDF: 0.00092
# 	Word: окаменелость	TD-IDF: 0.00092
# 	Word: музея —	TD-IDF: 0.00089
# 	Word: бурят	TD-IDF: 0.00089
# 	Word: заводский	TD-IDF: 0.00084
# 	Word: мы знать	TD-IDF: 0.00084
# 	Word: подстаканник	TD-IDF: 0.00084
# 	Word: о выставка	TD-IDF: 0.00084
# 	Word: в каком	TD-IDF: 0.00084
# 	Word: в раздел	TD-IDF: 0.00084
# 	Word: 100 рубль	TD-IDF: 0.00084
# 	Word: в прошлое	TD-IDF: 0.00084
# 	Word: на выставка	TD-IDF: 0.00083
# 	Word: и многий	TD-IDF: 0.00082
# 	Word: мамонт	TD-IDF: 0.00082
# 	Word: узнавать	TD-IDF: 0.00081
# 	Word: добрый	TD-IDF: 0.00081
# 	Word: по 19	TD-IDF: 0.00078
# 	Word: персонала	TD-IDF: 0.00078
# 	Word: и сообщить	TD-IDF: 0.00078
# 	Word: июля ть	TD-IDF: 0.00078
# 	Word: значения —	TD-IDF: 0.00078
# 	Word: с подлинный	TD-IDF: 0.00078
# 	Word: в 1916	TD-IDF: 0.00078
# 	Word: до настоящий	TD-IDF: 0.00078
# 	Word: междугородный	TD-IDF: 0.00078
# 	Word: от новосибирск	TD-IDF: 0.00078
# 	Word: в старинный	TD-IDF: 0.00078
# 	Word: cибирский	TD-IDF: 0.00078
# 	Word: в типичный	TD-IDF: 0.00078
# 	Word: у котора	TD-IDF: 0.00078
# 	Word: о юность	TD-IDF: 0.00078
# 	Word: с древний	TD-IDF: 0.00078
# 	Word: мгн	TD-IDF: 0.00078
# 	Word: начале xx	TD-IDF: 0.00078
# 	Word: тофалар	TD-IDF: 0.00078
# 	Word: двор	TD-IDF: 0.00078
# 	Word: в среда	TD-IDF: 0.00077
# 	Word: накаливание	TD-IDF: 0.00077
# 	Word: в нашить	TD-IDF: 0.00077
# 	Word: 50 рубль	TD-IDF: 0.00077
# 	Word: корпус	TD-IDF: 0.00072
# 	Word: о жизнь	TD-IDF: 0.00072
# 	Word: в деть	TD-IDF: 0.00072
# 	Word: нгу	TD-IDF: 0.00072
# 	Word: эвенк	TD-IDF: 0.00072
# 	Word: ответ	TD-IDF: 0.00071
# 	Word: слава	TD-IDF: 0.00071
# 	Word: отчёт	TD-IDF: 0.0007
# 	Word: рюрик	TD-IDF: 0.00069
# 	Word: и дизайнер	TD-IDF: 0.00068
# 	Word: главпочтамт	TD-IDF: 0.00068
# 	Word: в регион	TD-IDF: 0.00068
# 	Word: коммутатор	TD-IDF: 0.00068
# 	Word: декадный	TD-IDF: 0.00068
# 	Word: и пр	TD-IDF: 0.00068
# 	Word: и бытовой	TD-IDF: 0.00068
# 	Word: и рассказать	TD-IDF: 0.00068
# 	Word: ненец	TD-IDF: 0.00068
# 	Word: заранее	TD-IDF: 0.00068
# 	Word: по адрес	TD-IDF: 0.00067
# 	Word: фанерный	TD-IDF: 0.00067
# 	Word: камис	TD-IDF: 0.00067
# 	Word: филиал	TD-IDF: 0.00066
# 	Word: пн	TD-IDF: 0.00066
# 	Word: инв	TD-IDF: 0.00062
# 	Word: челюсть	TD-IDF: 0.00062
# 	Word: в конец	TD-IDF: 0.00062
# 	Word: сентября ть	TD-IDF: 0.00061
# 	Word: шаговый	TD-IDF: 0.00061
# 	Word: особливый	TD-IDF: 0.00061
# 	Word: с семья	TD-IDF: 0.00061
# 	Word: долган	TD-IDF: 0.00061
# 	Word: субсидия	TD-IDF: 0.00059
# 	Word: приглашение	TD-IDF: 0.00057
# 	Word: в выставочный	TD-IDF: 0.00056
# 	Word: мая ть	TD-IDF: 0.00056
# 	Word: в зал	TD-IDF: 0.00056
# 	Word: в парка	TD-IDF: 0.00056
# 	Word: эвен	TD-IDF: 0.00056
# 	Word: хрущевский	TD-IDF: 0.00055
# 	Word: цоколь	TD-IDF: 0.00055
# 	Word: затрудняться	TD-IDF: 0.00055
# 	Word: городской	TD-IDF: 0.00053
# 	Word: игральный	TD-IDF: 0.00052
# 	Word: в свой	TD-IDF: 0.00052
# 	Word: угорский	TD-IDF: 0.00052
# 	Word: самка	TD-IDF: 0.00052
# 	Word: диковина	TD-IDF: 0.00052
# 	Word: услуга	TD-IDF: 0.0005
# 	Word: малочисленный	TD-IDF: 0.00049
# 	Word: пт	TD-IDF: 0.00048
# 	Word: сб	TD-IDF: 0.00048
# 	Word: колясочник	TD-IDF: 0.00048
# 	Word: перевоз	TD-IDF: 0.00048
# 	Word: магнитофон	TD-IDF: 0.00048
# 	Word: подгорный	TD-IDF: 0.00048
# 	Word: по 12	TD-IDF: 0.00048
# 	Word: 18 000 руб	TD-IDF: 0.00048
# 	Word: с 9−30	TD-IDF: 0.00048
# 	Word: с 10−30	TD-IDF: 0.00048
# 	Word: и вторник	TD-IDF: 0.00048
# 	Word: и оплачиваться	TD-IDF: 0.00048
# 	Word: с тк	TD-IDF: 0.00048
# 	Word: по предупреждение	TD-IDF: 0.00048
# 	Word: на охранять	TD-IDF: 0.00048
# 	Word: и передача	TD-IDF: 0.00048
# 	Word: и лиц‚	TD-IDF: 0.00048
# 	Word: сигнализации‚	TD-IDF: 0.00048
# 	Word: видеонаблюдения‚	TD-IDF: 0.00048
# 	Word: соцпакет	TD-IDF: 0.00048
# 	Word: на обработка	TD-IDF: 0.00048
# 	Word: кандидатурой‚	TD-IDF: 0.00048
# 	Word: свяжемся	TD-IDF: 0.00048
# 	Word: ахс	TD-IDF: 0.00048
# 	Word: 26 000 руб	TD-IDF: 0.00048
# 	Word: с 9−00	TD-IDF: 0.00048
# 	Word: по ахс	TD-IDF: 0.00048
# 	Word: и выполнение	TD-IDF: 0.00048
# 	Word: с крыша	TD-IDF: 0.00048
# 	Word: диспетчеризация	TD-IDF: 0.00048
# 	Word: грузый	TD-IDF: 0.00048
# 	Word: и пассажирский	TD-IDF: 0.00048
# 	Word: и отчётность	TD-IDF: 0.00048
# 	Word: стандартов‚	TD-IDF: 0.00048
# 	Word: норм‚	TD-IDF: 0.00048
# 	Word: правил‚	TD-IDF: 0.00048
# 	Word: пользователь пк	TD-IDF: 0.00048
# 	Word: от 10	TD-IDF: 0.00048
# 	Word: самоорганизации‚	TD-IDF: 0.00048
# 	Word: ответственность‚	TD-IDF: 0.00048
# 	Word: декретный	TD-IDF: 0.00048
# 	Word: т отпуск	TD-IDF: 0.00048
# 	Word: по уход	TD-IDF: 0.00048
# 	Word: за ребёнок	TD-IDF: 0.00048
# 	Word: и ботаник	TD-IDF: 0.00048
# 	Word: и этнография	TD-IDF: 0.00048
# 	Word: и фаянс	TD-IDF: 0.00048
# 	Word: и аудиозапись	TD-IDF: 0.00048
# 	Word: и кинофонд	TD-IDF: 0.00048
# 	Word: и план	TD-IDF: 0.00048
# 	Word: ламаистско	TD-IDF: 0.00048
# 	Word: и афиша	TD-IDF: 0.00048
# 	Word: на коляска	TD-IDF: 0.00048
# 	Word: охраны —	TD-IDF: 0.00048
# 	Word: ее невозможный	TD-IDF: 0.00048
# 	Word: по этаж	TD-IDF: 0.00048
# 	Word: в 2016 г	TD-IDF: 0.00048
# 	Word: и филиал	TD-IDF: 0.00048
# 	Word: и захотеться	TD-IDF: 0.00048
# 	Word: за один	TD-IDF: 0.00048
# 	Word: в 1910	TD-IDF: 0.00048
# 	Word: и торговый	TD-IDF: 0.00048
# 	Word: в подвале —	TD-IDF: 0.00048
# 	Word: а верхний	TD-IDF: 0.00048
# 	Word: на 1000	TD-IDF: 0.00048
# 	Word: и одноимённый	TD-IDF: 0.00048
# 	Word: по пятница	TD-IDF: 0.00048
# 	Word: и собирание	TD-IDF: 0.00048
# 	Word: пвхд	TD-IDF: 0.00048
# 	Word: тсо	TD-IDF: 0.00048
# 	Word: краеведческий музей	TD-IDF: 0.00048
# 	Word: музей природа	TD-IDF: 0.00048
# 	Word: и сибиряк	TD-IDF: 0.00048
# 	Word: о один	TD-IDF: 0.00048
# 	Word: и предприниматель	TD-IDF: 0.00048
# 	Word: в 1920−30	TD-IDF: 0.00048
# 	Word: на енисейский	TD-IDF: 0.00048
# 	Word: и энец	TD-IDF: 0.00048
# 	Word: в туруханский	TD-IDF: 0.00048
# 	Word: и селькуп	TD-IDF: 0.00048
# 	Word: на алтай	TD-IDF: 0.00048
# 	Word: в карагассия	TD-IDF: 0.00048
# 	Word: в районах р	TD-IDF: 0.00048
# 	Word: и туруханский	TD-IDF: 0.00048
# 	Word: а не мифический	TD-IDF: 0.00048
# 	Word: и отправление	TD-IDF: 0.00048
# 	Word: буряты —	TD-IDF: 0.00048
# 	Word: монголоязычный	TD-IDF: 0.00048
# 	Word: с 17	TD-IDF: 0.00048
# 	Word: в монголия	TD-IDF: 0.00048
# 	Word: скотоводтво	TD-IDF: 0.00048
# 	Word: у восточный	TD-IDF: 0.00048
# 	Word: у западный	TD-IDF: 0.00048
# 	Word: долганы —	TD-IDF: 0.00048
# 	Word: в таймырский	TD-IDF: 0.00048
# 	Word: в бассейн	TD-IDF: 0.00048
# 	Word: и пясина	TD-IDF: 0.00048
# 	Word: на енисей	TD-IDF: 0.00048
# 	Word: долганский —	TD-IDF: 0.00048
# 	Word: в их состав	TD-IDF: 0.00048
# 	Word: энца	TD-IDF: 0.00048
# 	Word: и енец	TD-IDF: 0.00048
# 	Word: карагас	TD-IDF: 0.00048
# 	Word: народа —	TD-IDF: 0.00048
# 	Word: в нижнеудинский	TD-IDF: 0.00048
# 	Word: на тофаларский	TD-IDF: 0.00048
# 	Word: тоджинец	TD-IDF: 0.00048
# 	Word: а предок	TD-IDF: 0.00048
# 	Word: хозяйства —	TD-IDF: 0.00048
# 	Word: и пушной	TD-IDF: 0.00048
# 	Word: на патрилинейный	TD-IDF: 0.00048
# 	Word: семьи —	TD-IDF: 0.00048
# 	Word: кетскома	TD-IDF: 0.00048
# 	Word: на пушной	TD-IDF: 0.00048
# 	Word: и рыболовство	TD-IDF: 0.00048
# 	Word: в 17−18	TD-IDF: 0.00048
# 	Word: и таёжный	TD-IDF: 0.00048
# 	Word: кетовый	TD-IDF: 0.00048
# 	Word: но с приход	TD-IDF: 0.00048
# 	Word: и миссионер	TD-IDF: 0.00048
# 	Word: ламут	TD-IDF: 0.00048
# 	Word: к тунгусый	TD-IDF: 0.00048
# 	Word: в эвенкийский	TD-IDF: 0.00048
# 	Word: и камчатский	TD-IDF: 0.00048
# 	Word: тунгусоязычный	TD-IDF: 0.00048
# 	Word: и к 17	TD-IDF: 0.00048
# 	Word: осваивоить	TD-IDF: 0.00048
# 	Word: в горный	TD-IDF: 0.00048
# 	Word: в прибрежный	TD-IDF: 0.00048
# 	Word: зоне —	TD-IDF: 0.00048
# 	Word: и промысловый	TD-IDF: 0.00048
# 	Word: с принятие	TD-IDF: 0.00048
# 	Word: от енисей	TD-IDF: 0.00048
# 	Word: до охотский	TD-IDF: 0.00048
# 	Word: на восток	TD-IDF: 0.00048
# 	Word: по левобережье	TD-IDF: 0.00048
# 	Word: и ангар	TD-IDF: 0.00048
# 	Word: не составлять	TD-IDF: 0.00048
# 	Word: и транспортный	TD-IDF: 0.00048
# 	Word: и шаманизм	TD-IDF: 0.00048
# 	Word: эвенков —	TD-IDF: 0.00048
# 	Word: тунгусы —	TD-IDF: 0.00048
# 	Word: и подкаменный	TD-IDF: 0.00048
# 	Word: из коренной	TD-IDF: 0.00048
# 	Word: в якутия	TD-IDF: 0.00048
# 	Word: в иркутский	TD-IDF: 0.00048
# 	Word: и красноярский	TD-IDF: 0.00048
# 	Word: к момент	TD-IDF: 0.00048
# 	Word: по уровень	TD-IDF: 0.00048
# 	Word: и общинный	TD-IDF: 0.00048
# 	Word: иммущественный	TD-IDF: 0.00048
# 	Word: и сословный	TD-IDF: 0.00048
# 	Word: тойон	TD-IDF: 0.00048
# 	Word: в подчинение	TD-IDF: 0.00048
# 	Word: кумалан	TD-IDF: 0.00048
# 	Word: и раб	TD-IDF: 0.00048
# 	Word: кулут	TD-IDF: 0.00048
# 	Word: фольклор —	TD-IDF: 0.00048
# 	Word: о богатырь	TD-IDF: 0.00048
# 	Word: и скотоводческий	TD-IDF: 0.00048
# 	Word: пмв	TD-IDF: 0.00048
# 	Word: краснозерский	TD-IDF: 0.00048
# 	Word: болотнинский	TD-IDF: 0.00048
# 	Word: купинский	TD-IDF: 0.00048
# 	Word: естественнонаучный	TD-IDF: 0.00047
# 	Word: занятие	TD-IDF: 0.00047
# 	Word: этнос	TD-IDF: 0.00046
# 	Word: новость	TD-IDF: 0.00045
# 	Word: в область	TD-IDF: 0.00045
# 	Word: карелин	TD-IDF: 0.00045
# 	Word: динамо	TD-IDF: 0.00045
# 	Word: буревестник	TD-IDF: 0.00045
# 	Word: в дом	TD-IDF: 0.00045
# 	Word: в миро	TD-IDF: 0.00045
# 	Word: животное	TD-IDF: 0.00044
# 	Word: якутия	TD-IDF: 0.00044
# 	Word: всеобщий	TD-IDF: 0.00043
# 	Word: пруд	TD-IDF: 0.00042
# 	Word: комфортность	TD-IDF: 0.00042
# 	Word: удовлетворённость	TD-IDF: 0.00042
# 	Word: по телефон	TD-IDF: 0.00042
# 	Word: морзе	TD-IDF: 0.00042
# 	Word: кабель	TD-IDF: 0.00042
# 	Word: чеканиться	TD-IDF: 0.00042
# 	Word: гарнизонный	TD-IDF: 0.00042
# 	Word: кратко	TD-IDF: 0.00039
# 	Word: по 30	TD-IDF: 0.00039
# 	Word: и пресечение	TD-IDF: 0.00039
